# %% [markdown]
# <a href="https://colab.research.google.com/github/omerozcn/ChildGuardHybrid/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# HÜCRE — Google Drive Bağlantısı ve Dataset Yolu
# Bu hücreyi childguardhybrid_colab.py'deki HÜCRE 2'nin yerine kullan

from google.colab import drive
drive.mount('/content/drive')

import os

# -------------------------------------------------------
# Drive'daki CSV dosyasının tam yolunu buraya gir
# Örnek: /content/drive/MyDrive/ChildGuard/ChildGuard_Cleaned.csv
# -------------------------------------------------------
DATASET_PATH = "/content/drive/MyDrive/ChildGuard/ChildGuard_Cleaned.csv"  # ← Kendi yolunla değiştir

# Dosyanın varlığını kontrol et
if os.path.exists(DATASET_PATH):
    print(f"✅ Dataset bulundu: {DATASET_PATH}")
else:
    print(f"❌ Dosya bulunamadı: {DATASET_PATH}")
    print("\nDrive'daki dosyalarını görmek için:")
    print("  !ls /content/drive/MyDrive/")
# Out:
# Mounted at /content/drive
# ✅ Dataset bulundu: /content/drive/MyDrive/ChildGuard/ChildGuard_Cleaned.csv

# %%
# -*- coding: utf-8 -*-
"""ChildGuard AI v2.0 — İki Aşamalı Eğitim (Google Colab)

AŞAMA 1 — Genel Zararlı İçerik Tespiti (tüm veri, Unknown dahil)
  → bert_general  : BERT binary classifier (0=güvenli, 1=zararlı)
  → xgboost_model : XGBoost binary classifier

AŞAMA 2 — Yaş Grubu Sınıflandırması (sadece etiketli yaş grubu verisi)
  → bert_age      : BERT multi-class (0=Younger, 1=Pre-Teen, 2=Teen)
  Girdi: Aşama 1'den zararlı (1) çıkan metinler
  Çıktı: Hangi yaş grubuna yönelik?

Kullanım:
  1. Runtime > Change runtime type > GPU (T4)
  2. Hücreleri sırayla çalıştır
"""

# ============================================================
# HÜCRE 1 — Kütüphane Kurulumu
# ============================================================
# @title Kurulum
# !pip install -q transformers datasets accelerate joblib seaborn xgboost optuna shap ipywidgets

# ============================================================
# HÜCRE 2 — Drive Bağlantısı
# ============================================================
# @title Drive Bağlantısı
from google.colab import drive
drive.mount('/content/drive')

DATASET_PATH = "/content/drive/MyDrive/ChildGuard/ChildGuard_Cleaned.csv"  # ← gerekirse düzenle

import os
if os.path.exists(DATASET_PATH):
    print(f"✅ Dataset bulundu: {DATASET_PATH}")
else:
    print(f"❌ Bulunamadı. Klasörü kontrol et: !ls '/content/drive/MyDrive/'")

# ============================================================
# HÜCRE 3 — Import'lar ve Ayarlar
# ============================================================
# @title Import'lar

import os, re, shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import torch
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from transformers import (
    BertTokenizer,
    BertForSequenceClassification,
    get_linear_schedule_with_warmup,
)
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import (
    accuracy_score, confusion_matrix,
    precision_recall_fscore_support, classification_report,
)
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack, csr_matrix
import xgboost as xgb
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)
import shap
from tqdm.auto import tqdm

# ---- Sabitler ----
TEXT          = "text"
TARGET        = "actual_class"
AGE_GROUP_COL = "Age_Group"
MAX_LEN       = 128
BATCH_SIZE    = 16
EPOCHS        = 3
DEVICE        = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Yaş grubu → integer etiket eşlemesi (Aşama 2)
AGE_LABEL_MAP = {
    "Younger Children (Under 11)": 0,
    "Pre-Teens (11–12)":           1,
    "Teens (13–17)":               2,
}
AGE_LABEL_NAMES = ["Younger", "Pre-Teen", "Teen"]

os.makedirs("final_models", exist_ok=True)
print("✅ Ortam hazır.")
print(f"   PyTorch : {torch.__version__}")
print(f"   Device  : {DEVICE}")
print(f"   XGBoost : {xgb.__version__}")

# ============================================================
# HÜCRE 4 — Dataset Yükleme ve Temizleme
# ============================================================
# @title Dataset Yükleme

df_raw = pd.read_csv(DATASET_PATH, encoding="cp1252")
df_raw = df_raw.dropna(subset=[TEXT, TARGET, AGE_GROUP_COL])
df_raw[TARGET] = df_raw[TARGET].astype(float)

def clean_text(text: str) -> str:
    text = str(text).lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"[^a-zA-Z0-9\s!?.,]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df_raw[TEXT] = df_raw[TEXT].apply(clean_text)

print(f"✅ Dataset: {len(df_raw):,} satır")
print(f"\nAGE GROUP:\n{df_raw[AGE_GROUP_COL].value_counts()}")
print(f"\nACTUAL CLASS:\n{df_raw[TARGET].value_counts()}")

# ============================================================
# HÜCRE 5 — Tokenizer ve Yardımcı Sınıflar
# ============================================================
# @title Tokenizer

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

class BinaryDataset(Dataset):
    """Aşama 1: 0/1 zararlı tespiti"""
    def __init__(self, texts, labels):
        self.enc    = tokenizer(texts, truncation=True, padding=True,
                                max_length=MAX_LEN, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self): return len(self.labels)

    def __getitem__(self, idx):
        return {
            "input_ids":      self.enc["input_ids"][idx],
            "attention_mask": self.enc["attention_mask"][idx],
            "labels":         self.labels[idx],
        }

class MultiClassDataset(Dataset):
    """Aşama 2: yaş grubu sınıflandırması (3 sınıf)"""
    def __init__(self, texts, labels):
        self.enc    = tokenizer(texts, truncation=True, padding=True,
                                max_length=MAX_LEN, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self): return len(self.labels)

    def __getitem__(self, idx):
        return {
            "input_ids":      self.enc["input_ids"][idx],
            "attention_mask": self.enc["attention_mask"][idx],
            "labels":         self.labels[idx],
        }

def train_bert_model(train_loader, val_loader, num_labels, save_path):
    model = BertForSequenceClassification.from_pretrained(
        "bert-base-uncased", num_labels=num_labels
    )
    model.to(DEVICE)

    optimizer   = AdamW(model.parameters(), lr=2e-5)
    total_steps = len(train_loader) * EPOCHS
    scheduler   = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=int(0.1 * total_steps),
        num_training_steps=total_steps,
    )

    best_val_acc, best_state = 0.0, None

    for epoch in range(EPOCHS):
        # ── Eğitim ──
        model.train()
        running_loss, correct_tr, total_tr = 0.0, 0, 0

        pbar = tqdm(train_loader,
                    desc=f"Ep {epoch+1}/{EPOCHS} Train",
                    unit="batch", leave=True)

        for step, batch in enumerate(pbar, 1):
            optimizer.zero_grad()
            out = model(
                input_ids=batch["input_ids"].to(DEVICE),
                attention_mask=batch["attention_mask"].to(DEVICE),
                labels=batch["labels"].to(DEVICE),
            )
            out.loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step(); scheduler.step()

            running_loss += out.loss.item()
            preds         = out.logits.argmax(dim=1).cpu()
            correct_tr   += (preds == batch["labels"]).sum().item()
            total_tr     += len(batch["labels"])

            pbar.set_postfix(
                loss=f"{running_loss/step:.4f}",
                acc=f"{correct_tr/total_tr:.4f}",
                lr=f"{scheduler.get_last_lr()[0]:.1e}",
            )

        # ── Validasyon ──
        model.eval()
        correct_v, total_v, val_loss = 0, 0, 0.0

        vbar = tqdm(val_loader,
                    desc=f"Ep {epoch+1}/{EPOCHS} Val  ",
                    unit="batch", leave=True)

        with torch.no_grad():
            for batch in vbar:
                out_v = model(
                    input_ids=batch["input_ids"].to(DEVICE),
                    attention_mask=batch["attention_mask"].to(DEVICE),
                    labels=batch["labels"].to(DEVICE),
                )
                val_loss  += out_v.loss.item()
                preds_v    = out_v.logits.argmax(dim=1).cpu()
                correct_v += (preds_v == batch["labels"]).sum().item()
                total_v   += len(batch["labels"])
                vbar.set_postfix(
                    val_loss=f"{val_loss/(vbar.n+1):.4f}",
                    val_acc=f"{correct_v/total_v:.4f}",
                )

        val_acc = correct_v / total_v
        flag    = " ✅ en iyi" if val_acc > best_val_acc else ""
        print(f"  → Epoch {epoch+1} | "
              f"train_acc={correct_tr/total_tr:.4f} | "
              f"val_acc={val_acc:.4f}{flag}\n")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state   = {k: v.clone() for k, v in model.state_dict().items()}

    model.load_state_dict(best_state)
    model.save_pretrained(save_path)
    tokenizer.save_pretrained(save_path)
    print(f"  💾 Kaydedildi → {save_path}  (best val_acc={best_val_acc:.4f})")
    return model

def get_bert_probs(model, texts):
    """Verilen metinler için BERT olasılık skoru döndürür."""
    model.eval()
    ds     = BinaryDataset(texts, [0] * len(texts))
    loader = DataLoader(ds, batch_size=BATCH_SIZE)
    probs  = []
    with torch.no_grad():
        for batch in loader:
            logits = model(
                input_ids=batch["input_ids"].to(DEVICE),
                attention_mask=batch["attention_mask"].to(DEVICE),
            ).logits
            p = torch.softmax(logits, dim=1)[:, 1].cpu().numpy()
            probs.extend(p)
    return np.array(probs)

print("✅ Tokenizer ve yardımcı sınıflar hazır.")

# ============================================================
# HÜCRE 6 — AŞAMA 1: Genel BERT Eğitimi (tüm veri)
# ⚠️  ~30–50 dk
# ============================================================
# @title Aşama 1 — Genel BERT

print("=" * 60)
print(" AŞAMA 1: Genel Zararlı İçerik Tespiti (tüm veri)")
print("=" * 60)

X_all = df_raw[TEXT].tolist()
y_all = df_raw[TARGET].astype(int).tolist()

X_tr, X_te, y_tr, y_te = train_test_split(
    X_all, y_all, test_size=0.2, random_state=42, stratify=y_all)
X_tr, X_va, y_tr, y_va = train_test_split(
    X_tr, y_tr, test_size=0.1, random_state=42, stratify=y_tr)

# Oversampling (azınlık = zararlı sınıf)
df_tr  = pd.DataFrame({"text": X_tr, "label": y_tr})
df_maj = df_tr[df_tr.label == 0]
df_min = df_tr[df_tr.label == 1]
df_min_up = resample(df_min, replace=True, n_samples=len(df_maj), random_state=42)
df_up = pd.concat([df_maj, df_min_up]).sample(frac=1, random_state=42)

train_loader = DataLoader(
    BinaryDataset(df_up["text"].tolist(), df_up["label"].tolist()),
    batch_size=BATCH_SIZE, shuffle=True)
val_loader  = DataLoader(BinaryDataset(X_va, y_va),  batch_size=BATCH_SIZE)
test_loader = DataLoader(BinaryDataset(X_te, y_te),  batch_size=BATCH_SIZE)

bert_general = train_bert_model(
    train_loader, val_loader,
    num_labels=2,
    save_path="final_models/bert_general",
)

# Threshold tuning
all_probs  = get_bert_probs(bert_general, X_te)
all_labels = np.array(y_te)

best_f1, best_thr, best_preds = -1, 0.5, None
for thr in np.linspace(0.3, 0.7, 20):
    preds = (all_probs >= thr).astype(int)
    f1    = precision_recall_fscore_support(all_labels, preds, average="binary")[2]
    if f1 > best_f1:
        best_f1, best_thr, best_preds = f1, thr, preds

joblib.dump({"threshold": best_thr}, "final_models/bert_general_config.pkl")
print(f"\n  Threshold: {best_thr:.2f} | F1: {best_f1:.4f}")
print("\n--- GENEL BERT TEST RAPORU ---")
print(classification_report(all_labels, best_preds, target_names=["Güvenli", "Zararlı"]))

# Confusion matrix
cm = confusion_matrix(all_labels, best_preds)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Güvenli", "Zararlı"],
            yticklabels=["Güvenli", "Zararlı"])
plt.title(f"Genel BERT (thr={best_thr:.2f})")
plt.ylabel("Gerçek"); plt.xlabel("Tahmin")
plt.tight_layout(); plt.show()

# ============================================================
# HÜCRE 7 — AŞAMA 1: XGBoost Eğitimi (DÜZELTİLMİŞ)
# ============================================================
# @title Aşama 1 — XGBoost

print("=" * 60)
print(" AŞAMA 1: XGBoost (tüm veri)")
print("=" * 60)

df_xgb = df_raw.copy()
df_xgb["text_len"] = df_xgb[TEXT].str.len()
df_xgb["word_cnt"] = df_xgb[TEXT].str.split().str.len()

age_dummies = pd.get_dummies(df_xgb[AGE_GROUP_COL], prefix="AgeGroup")
AGE_GROUP_COLUMNS = list(age_dummies.columns)
joblib.dump(AGE_GROUP_COLUMNS, "final_models/age_group_columns.pkl")
print(f"Age group sütunları: {AGE_GROUP_COLUMNS}")

X_meta = df_xgb[["text_len", "word_cnt"]]
y_xgb  = df_xgb[TARGET].astype(int)
texts  = df_xgb[TEXT]

(X_m_tr, X_m_te,
 y_tr_x, y_te_x,
 t_tr,   t_te,
 age_tr, age_te) = train_test_split(
    X_meta, y_xgb, texts, age_dummies,
    test_size=0.2, random_state=42, stratify=y_xgb,
)

vectorizer    = TfidfVectorizer(max_features=5000, min_df=5)
X_tr_tfidf    = vectorizer.fit_transform(t_tr)
X_te_tfidf    = vectorizer.transform(t_te)

age_te = age_te.reindex(columns=age_tr.columns, fill_value=0)

X_tr_final = hstack([X_tr_tfidf, csr_matrix(X_m_tr.values), csr_matrix(age_tr.values)])
X_te_final = hstack([X_te_tfidf, csr_matrix(X_m_te.values), csr_matrix(age_te.values)])

neg = (y_tr_x == 0).sum(); pos = (y_tr_x == 1).sum()
scale_pos_weight = neg / pos
print(f"scale_pos_weight = {scale_pos_weight:.3f}")

# ── DÜZELTİLDİ: device="cpu" — sparse matrix CPU'da, model de CPU'da olmalı ──
def xgb_objective(trial):
    params = {
        "n_estimators":     trial.suggest_int  ("n_estimators",     100, 800, step=50),
        "max_depth":        trial.suggest_int  ("max_depth",          3,  10),
        "learning_rate":    trial.suggest_float("learning_rate",    0.01, 0.3, log=True),
        "subsample":        trial.suggest_float("subsample",         0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree",  0.5, 1.0),
        "min_child_weight": trial.suggest_int  ("min_child_weight",    1,  10),
        "scale_pos_weight": scale_pos_weight,
        "eval_metric":      "logloss",
        "random_state":     42,
        "tree_method":      "hist",
        "device":           "cpu",   # ← sparse matrix ile uyumlu
    }
    clf = xgb.XGBClassifier(**params)
    clf.fit(X_tr_final, y_tr_x, verbose=False)
    preds = clf.predict(X_te_final)
    return precision_recall_fscore_support(y_te_x, preds, average="binary")[2]

print("Optuna araması (50 deneme)...")
study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(xgb_objective, n_trials=50, show_progress_bar=True)
print(f"✅ En iyi F1: {study.best_value:.4f} | Params: {study.best_params}")

best_xgb_params = {
    **study.best_params,
    "scale_pos_weight": scale_pos_weight,
    "eval_metric":      "logloss",
    "random_state":     42,
    "tree_method":      "hist",
    "device":           "cpu",
}
best_xgb = xgb.XGBClassifier(**best_xgb_params)
best_xgb.fit(X_tr_final, y_tr_x, verbose=False)

joblib.dump(best_xgb,   "final_models/xgboost_model.pkl")
joblib.dump(vectorizer, "final_models/tfidf_vectorizer.pkl")

y_pred_xgb = best_xgb.predict(X_te_final)
print("\n--- XGBOOST TEST RAPORU ---")
print(classification_report(y_te_x, y_pred_xgb, target_names=["Güvenli", "Zararlı"]))

cm_xgb = confusion_matrix(y_te_x, y_pred_xgb)
plt.figure(figsize=(5, 4))
sns.heatmap(cm_xgb, annot=True, fmt="d", cmap="Greens",
            xticklabels=["Güvenli", "Zararlı"], yticklabels=["Güvenli", "Zararlı"])
plt.title("XGBoost — Genel"); plt.ylabel("Gerçek"); plt.xlabel("Tahmin")
plt.tight_layout(); plt.show()

# ============================================================
# HÜCRE 8 — SHAP Doğrulaması
# ============================================================
# @title SHAP Analizi

feature_names = (
    vectorizer.get_feature_names_out().tolist()
    + ["text_len", "word_cnt"]
    + AGE_GROUP_COLUMNS
)

explainer   = shap.TreeExplainer(best_xgb)
X_sample    = X_te_final.toarray()[:200]
shap_values = explainer.shap_values(X_sample)

shap.summary_plot(shap_values, X_sample, feature_names=feature_names,
                  max_display=15, show=True)
print("✅ SHAP grafiği hazır.")

# ============================================================
# HÜCRE 9 — AŞAMA 2: Yaş Grubu BERT Eğitimi
# ⚠️  ~20–30 dk
# ============================================================
# @title Aşama 2 — Yaş Grubu Sınıflandırması

print("=" * 60)
print(" AŞAMA 2: Yaş Grubu Sınıflandırması")
print(" Girdi: Yalnızca zararlı (actual_class=1) + bilinen yaş grubu")
print("=" * 60)

# Sadece bilinen yaş grubu + zararlı kayıtlar
df_age = df_raw[
    (df_raw[AGE_GROUP_COL] != "Unknown") &
    (df_raw[TARGET] == 1.0)
].copy()

# Encoding — CSV'deki gerçek değerlere göre eşle
# (encoding hatalarına karşı normalize et)
def normalize_age_group(val):
    v = str(val).lower()
    if "under 11" in v or "younger" in v:
        return 0  # Younger
    if "11" in v or "pre" in v:
        return 1  # Pre-Teen
    if "13" in v or "teen" in v:
        return 2  # Teen
    return -1

df_age["age_label"] = df_age[AGE_GROUP_COL].apply(normalize_age_group)
df_age = df_age[df_age["age_label"] >= 0]

print(f"Yaş grubu eğitim verisi: {len(df_age):,} zararlı örnek")
print(df_age["age_label"].value_counts().rename({0:"Younger", 1:"Pre-Teen", 2:"Teen"}))

X_age = df_age[TEXT].tolist()
y_age = df_age["age_label"].tolist()

X_tr_a, X_te_a, y_tr_a, y_te_a = train_test_split(
    X_age, y_age, test_size=0.2, random_state=42, stratify=y_age)
X_tr_a, X_va_a, y_tr_a, y_va_a = train_test_split(
    X_tr_a, y_tr_a, test_size=0.1, random_state=42, stratify=y_tr_a)

# Oversampling (3 sınıf dengesi)
df_tr_a  = pd.DataFrame({"text": X_tr_a, "label": y_tr_a})
max_size = df_tr_a["label"].value_counts().max()
balanced = pd.concat([
    resample(df_tr_a[df_tr_a.label == cls],
             replace=True, n_samples=max_size, random_state=42)
    for cls in [0, 1, 2]
]).sample(frac=1, random_state=42)

train_loader_a = DataLoader(
    MultiClassDataset(balanced["text"].tolist(), balanced["label"].tolist()),
    batch_size=BATCH_SIZE, shuffle=True)
val_loader_a = DataLoader(
    MultiClassDataset(X_va_a, y_va_a), batch_size=BATCH_SIZE)

bert_age = train_bert_model(
    train_loader_a, val_loader_a,
    num_labels=3,
    save_path="final_models/bert_age_group",
)

# Test
bert_age.eval()
all_preds_a, all_labels_a = [], []
test_ds_a = MultiClassDataset(X_te_a, y_te_a)
with torch.no_grad():
    for batch in DataLoader(test_ds_a, batch_size=BATCH_SIZE):
        preds = bert_age(
            input_ids=batch["input_ids"].to(DEVICE),
            attention_mask=batch["attention_mask"].to(DEVICE),
        ).logits.argmax(dim=1).cpu().numpy()
        all_preds_a.extend(preds)
        all_labels_a.extend(batch["labels"].numpy())

print("\n--- YAŞ GRUBU SINIFLANDIRMA RAPORU ---")
print(classification_report(all_labels_a, all_preds_a,
                             target_names=AGE_LABEL_NAMES))

cm_age = confusion_matrix(all_labels_a, all_preds_a)
plt.figure(figsize=(6, 5))
sns.heatmap(cm_age, annot=True, fmt="d", cmap="Purples",
            xticklabels=AGE_LABEL_NAMES, yticklabels=AGE_LABEL_NAMES)
plt.title("Yaş Grubu Sınıflandırıcı")
plt.ylabel("Gerçek"); plt.xlabel("Tahmin")
plt.tight_layout(); plt.show()

# Etiket → isim eşlemesini kaydet
joblib.dump(AGE_LABEL_NAMES, "final_models/age_label_names.pkl")

# ============================================================
# HÜCRE 10 — ZIP Paketleme ve İndirme
# ============================================================
# @title Modelleri İndir

print("\n=== ÖZET ===")
print("final_models/ içeriği:")
for f in sorted(os.listdir("final_models")):
    path = os.path.join("final_models", f)
    if os.path.isdir(path):
        print(f"  📁 {f}/")
    else:
        size = os.path.getsize(path) / 1024
        print(f"  📄 {f}  ({size:.1f} KB)")

shutil.make_archive("ChildGuard_v2_Bundle", "zip", "final_models")
print("\n✅ ChildGuard_v2_Bundle.zip hazır.")

from google.colab import files
files.download("ChildGuard_v2_Bundle.zip")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.4 MB/s eta 0:00:00
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Dataset bulundu: /content/drive/MyDrive/ChildGuard/ChildGuard_Cleaned.csv
# ✅ Ortam hazır.
#    PyTorch : 2.10.0+cu128
#    Device  : cuda
#    XGBoost : 3.2.0
# ✅ Dataset: 262,598 satır
#
# AGE GROUP:
# Age_Group
# Unknown                        220043
# Younger Children (Under 11)     28389
# Teens (13â€“17)                  9355
# Pre-Teens (11â€“12)              4811
# Name: count, dtype: int64
#
# ACTUAL CLASS:
# actual_class
# 0.0    218793
# 1.0     43805
# Name: count, dtype: int64
# ✅ Tokenizer ve yardımcı sınıflar hazır.
# ============================================================
#  AŞAMA 1: Genel Zararlı İçerik Tespiti (tüm veri)
# ============================================================
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Ep 1/3 Train:   0%|          | 0/19692 [00:00<?, ?batch/s]
# Ep 1/3 Val  :   0%|          | 0/1313 [00:00<?, ?batch/s]
#   → Epoch 1 | train_acc=0.8852 | val_acc=0.8940 ✅ en iyi
# Ep 2/3 Train:   0%|          | 0/19692 [00:00<?, ?batch/s]
# Ep 2/3 Val  :   0%|          | 0/1313 [00:00<?, ?batch/s]
#   → Epoch 2 | train_acc=0.9618 | val_acc=0.9122 ✅ en iyi
# Ep 3/3 Train:   0%|          | 0/19692 [00:00<?, ?batch/s]
# Ep 3/3 Val  :   0%|          | 0/1313 [00:00<?, ?batch/s]
#   → Epoch 3 | train_acc=0.9864 | val_acc=0.9117
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
#   💾 Kaydedildi → final_models/bert_general  (best val_acc=0.9122)
#
#   Threshold: 0.32 | F1: 0.7438
#
# --- GENEL BERT TEST RAPORU ---
#               precision    recall  f1-score   support
#
#      Güvenli       0.95      0.95      0.95     43759
#      Zararlı       0.74      0.75      0.74      8761
#
#     accuracy                           0.91     52520
#    macro avg       0.84      0.85      0.85     52520
# weighted avg       0.91      0.91      0.91     52520
# ============================================================
#  AŞAMA 1: XGBoost (tüm veri)
# ============================================================
# Age group sütunları: ['AgeGroup_Pre-Teens (11â€“12)', 'AgeGroup_Teens (13â€“17)', 'AgeGroup_Unknown', 'AgeGroup_Younger Children (Under 11)']
# scale_pos_weight = 4.995
# Optuna araması (30 deneme)...
#   0%|          | 0/30 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py:751: UserWarning: [19:49:24] WARNING: /__w/xgboost/xgboost/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# ✅ En iyi F1: 0.3495 | Params: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.1946877190679732, 'subsample': 0.8669458434775559, 'colsample_bytree': 0.7020843771180812}
#
# --- XGBOOST TEST RAPORU ---
#               precision    recall  f1-score   support
#
#      Güvenli       0.89      0.57      0.70     43759
#      Zararlı       0.24      0.66      0.35      8761
#
#     accuracy                           0.59     52520
#    macro avg       0.57      0.62      0.52     52520
# weighted avg       0.79      0.59      0.64     52520
# ✅ SHAP grafiği hazır.
# ============================================================
#  AŞAMA 2: Yaş Grubu Sınıflandırması
#  Girdi: Yalnızca zararlı (actual_class=1) + bilinen yaş grubu
# ============================================================
# Yaş grubu eğitim verisi: 8,575 zararlı örnek
# age_label
# Younger     3543
# Teen        3503
# Pre-Teen    1529
# Name: count, dtype: int64
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Ep 1/3 Train:   0%|          | 0/479 [00:00<?, ?batch/s]
# Ep 1/3 Val  :   0%|          | 0/43 [00:00<?, ?batch/s]
#   → Epoch 1 | train_acc=0.6690 | val_acc=0.8703 ✅ en iyi
# Ep 2/3 Train:   0%|          | 0/479 [00:00<?, ?batch/s]
# Ep 2/3 Val  :   0%|          | 0/43 [00:00<?, ?batch/s]
#   → Epoch 2 | train_acc=0.9388 | val_acc=0.9184 ✅ en iyi
# Ep 3/3 Train:   0%|          | 0/479 [00:00<?, ?batch/s]
# Ep 3/3 Val  :   0%|          | 0/43 [00:00<?, ?batch/s]
#   → Epoch 3 | train_acc=0.9818 | val_acc=0.9169
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
#   💾 Kaydedildi → final_models/bert_age_group  (best val_acc=0.9184)
#
# --- YAŞ GRUBU SINIFLANDIRMA RAPORU ---
#               precision    recall  f1-score   support
#
#      Younger       0.89      0.89      0.89       709
#     Pre-Teen       0.88      0.91      0.89       306
#         Teen       0.93      0.91      0.92       700
#
#     accuracy                           0.90      1715
#    macro avg       0.90      0.90      0.90      1715
# weighted avg       0.90      0.90      0.90      1715
# === ÖZET ===
# final_models/ içeriği:
#   📄 age_group_columns.pkl  (0.1 KB)
#   📄 age_label_names.pkl  (0.0 KB)
#   📁 bert_age_group/
#   📁 bert_general/
#   📄 bert_general_config.pkl  (0.1 KB)
#   📁 bert_pre_teen/
#   📁 bert_teen/
#   📄 tfidf_vectorizer.pkl  (178.6 KB)
#   📄 xgboost_model.pkl  (686.3 KB)
#
# ✅ ChildGuard_v2_Bundle.zip hazır.

# %%
# Kontrol hücresi — dataseti tanı
print("=== KOLONLAR ===")
print(df_raw.columns.tolist())

print("\n=== AGE GROUP DAĞILIMI ===")
print(df_raw["Age_Group"].value_counts())

print("\n=== ACTUAL CLASS DAĞILIMI (tüm veri) ===")
print(df_raw["actual_class"].value_counts())

print("\n=== ACTUAL CLASS — sadece Unknown'lar ===")
print(df_raw[df_raw["Age_Group"] == "Unknown"]["actual_class"].value_counts())

print("\n=== İLK 3 SATIR ===")
print(df_raw.head(3).to_string())
# Out:
# === KOLONLAR ===
# ['text', 'actual_class', 'predicted_class', 'Age_Group']
#
# === AGE GROUP DAĞILIMI ===
# Age_Group
# Unknown                        220043
# Younger Children (Under 11)     28389
# Teens (13â€“17)                  9355
# Pre-Teens (11â€“12)              4811
# Name: count, dtype: int64
#
# === ACTUAL CLASS DAĞILIMI (tüm veri) ===
# actual_class
# 0.0    218793
# 1.0     43805
# Name: count, dtype: int64
#
# === ACTUAL CLASS — sadece Unknown'lar ===
# actual_class
# 0.0    184813
# 1.0     35230
# Name: count, dtype: int64
#
# === İLK 3 SATIR ===
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text  actual_class  predicted_class Age_Group
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   personally agree sailor cuteness favour change picture           0.0              0.0   Unknown
# 1  ultimate pi day history claim ultimate pi moment occur march 14 1592 653 58 second fact assemble moment possible actuate clock minute hand second invent jost brgi 1577 handful astronomer ludolph van ceulen publish 20 digit pi 1596 11 16 digit know time gregorian calendar inaugurate 1582 european country increase talk date time conversion help possible mathematician access brgi rare clock pi day connection 10or 12 digit close 3141592 matter date format mm dd yyyy dd mm yyyy use modern time pretty rule possibility realize significance 53 minute past 6 o clock 14th day march 1592           0.0              0.0   Unknown
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                wait home           0.0              0.0   Unknown

# %%
import os
if os.path.exists("ChildGuard_v2_Bundle.zip"):
    print("✅ ZIP mevcut, indiriliyor...")
    from google.colab import files
    files.download("ChildGuard_v2_Bundle.zip")
else:
    print("❌ ZIP yok, session kapanmış.")
    print(os.listdir("final_models") if os.path.exists("final_models") else "final_models da yok")
# Out:
# ❌ ZIP yok, session kapanmış.
# final_models da yok

# %%
# -*- coding: utf-8 -*-
"""ChildGuard AI v2.0 — İki Aşamalı Eğitim (Google Colab)

AŞAMA 1 — Genel Zararlı İçerik Tespiti (tüm veri, Unknown dahil)
  → bert_general  : BERT binary classifier (0=güvenli, 1=zararlı)
  → xgboost_model : XGBoost binary classifier

AŞAMA 2 — Yaş Grubu Sınıflandırması (sadece etiketli yaş grubu verisi)
  → bert_age_group : BERT multi-class (0=Younger, 1=Pre-Teen, 2=Teen)

Kullanım:
  1. Runtime > Change runtime type > GPU (T4)
  2. Hücreleri sırayla çalıştır
"""

# ============================================================
# HÜCRE 1 — Kütüphane Kurulumu
# ============================================================
# @title Kurulum
# !pip install -q transformers datasets accelerate joblib seaborn xgboost optuna shap ipywidgets

# ============================================================
# HÜCRE 2 — Drive Bağlantısı
# ============================================================
# @title Drive Bağlantısı
from google.colab import drive
drive.mount('/content/drive')

DATASET_PATH   = "/content/drive/MyDrive/ChildGuard/ChildGuard_Cleaned.csv"
DRIVE_SAVE_DIR = "/content/drive/MyDrive/ChildGuard/final_models_v2"

import os
if os.path.exists(DATASET_PATH):
    print(f"✅ Dataset bulundu: {DATASET_PATH}")
else:
    print(f"❌ Bulunamadı. Kontrol et: !ls '/content/drive/MyDrive/ChildGuard/'")

# ============================================================
# HÜCRE 3 — Import'lar ve Ayarlar
# ============================================================
# @title Import'lar

import os, re, shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import torch
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from transformers import (
    BertTokenizer,
    BertForSequenceClassification,
    get_linear_schedule_with_warmup,
)
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import (
    accuracy_score, confusion_matrix,
    precision_recall_fscore_support, classification_report,
)
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack, csr_matrix
import xgboost as xgb
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)
import shap
from tqdm.auto import tqdm

TEXT          = "text"
TARGET        = "actual_class"
AGE_GROUP_COL = "Age_Group"
MAX_LEN       = 128
BATCH_SIZE    = 16
EPOCHS        = 3
DEVICE        = torch.device("cuda" if torch.cuda.is_available() else "cpu")
AGE_LABEL_NAMES = ["Younger", "Pre-Teen", "Teen"]

os.makedirs("final_models", exist_ok=True)
print("✅ Ortam hazır.")
print(f"   PyTorch : {torch.__version__}")
print(f"   Device  : {DEVICE}")
print(f"   XGBoost : {xgb.__version__}")

# ============================================================
# HÜCRE 4 — Dataset Yükleme
# ============================================================
# @title Dataset Yükleme

df_raw = pd.read_csv(DATASET_PATH, encoding="cp1252")
df_raw = df_raw.dropna(subset=[TEXT, TARGET, AGE_GROUP_COL])
df_raw[TARGET] = df_raw[TARGET].astype(float)

def clean_text(text: str) -> str:
    text = str(text).lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"[^a-zA-Z0-9\s!?.,]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df_raw[TEXT] = df_raw[TEXT].apply(clean_text)
print(f"✅ Dataset: {len(df_raw):,} satır")
print(f"\nAGE GROUP:\n{df_raw[AGE_GROUP_COL].value_counts()}")
print(f"\nACTUAL CLASS:\n{df_raw[TARGET].value_counts()}")

# ============================================================
# HÜCRE 5 — Tokenizer ve Yardımcı Sınıflar
# ============================================================
# @title Tokenizer

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

class BinaryDataset(Dataset):
    def __init__(self, texts, labels):
        self.enc    = tokenizer(texts, truncation=True, padding=True,
                                max_length=MAX_LEN, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)
    def __len__(self): return len(self.labels)
    def __getitem__(self, idx):
        return {
            "input_ids":      self.enc["input_ids"][idx],
            "attention_mask": self.enc["attention_mask"][idx],
            "labels":         self.labels[idx],
        }

class MultiClassDataset(Dataset):
    def __init__(self, texts, labels):
        self.enc    = tokenizer(texts, truncation=True, padding=True,
                                max_length=MAX_LEN, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)
    def __len__(self): return len(self.labels)
    def __getitem__(self, idx):
        return {
            "input_ids":      self.enc["input_ids"][idx],
            "attention_mask": self.enc["attention_mask"][idx],
            "labels":         self.labels[idx],
        }

def train_bert_model(train_loader, val_loader, num_labels, save_path):
    model = BertForSequenceClassification.from_pretrained(
        "bert-base-uncased", num_labels=num_labels)
    model.to(DEVICE)

    optimizer   = AdamW(model.parameters(), lr=2e-5)
    total_steps = len(train_loader) * EPOCHS
    scheduler   = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=int(0.1 * total_steps),
        num_training_steps=total_steps,
    )
    best_val_acc, best_state = 0.0, None

    for epoch in range(EPOCHS):
        model.train()
        running_loss, correct_tr, total_tr = 0.0, 0, 0
        pbar = tqdm(train_loader, desc=f"Ep {epoch+1}/{EPOCHS} Train", unit="batch", leave=True)
        for step, batch in enumerate(pbar, 1):
            optimizer.zero_grad()
            out = model(
                input_ids=batch["input_ids"].to(DEVICE),
                attention_mask=batch["attention_mask"].to(DEVICE),
                labels=batch["labels"].to(DEVICE),
            )
            out.loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step(); scheduler.step()
            running_loss += out.loss.item()
            preds         = out.logits.argmax(dim=1).cpu()
            correct_tr   += (preds == batch["labels"]).sum().item()
            total_tr     += len(batch["labels"])
            pbar.set_postfix(
                loss=f"{running_loss/step:.4f}",
                acc=f"{correct_tr/total_tr:.4f}",
                lr=f"{scheduler.get_last_lr()[0]:.1e}",
            )

        model.eval()
        correct_v, total_v, val_loss = 0, 0, 0.0
        vbar = tqdm(val_loader, desc=f"Ep {epoch+1}/{EPOCHS} Val  ", unit="batch", leave=True)
        with torch.no_grad():
            for batch in vbar:
                out_v = model(
                    input_ids=batch["input_ids"].to(DEVICE),
                    attention_mask=batch["attention_mask"].to(DEVICE),
                    labels=batch["labels"].to(DEVICE),
                )
                val_loss  += out_v.loss.item()
                preds_v    = out_v.logits.argmax(dim=1).cpu()
                correct_v += (preds_v == batch["labels"]).sum().item()
                total_v   += len(batch["labels"])
                vbar.set_postfix(
                    val_loss=f"{val_loss/(vbar.n+1):.4f}",
                    val_acc=f"{correct_v/total_v:.4f}",
                )

        val_acc = correct_v / total_v
        flag    = " ✅ en iyi" if val_acc > best_val_acc else ""
        print(f"  → Epoch {epoch+1} | train_acc={correct_tr/total_tr:.4f} | val_acc={val_acc:.4f}{flag}\n")
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state   = {k: v.clone() for k, v in model.state_dict().items()}

    model.load_state_dict(best_state)
    model.save_pretrained(save_path)
    tokenizer.save_pretrained(save_path)
    print(f"  💾 Kaydedildi → {save_path}  (best val_acc={best_val_acc:.4f})")
    return model

def get_bert_probs(model, texts):
    model.eval()
    ds     = BinaryDataset(texts, [0] * len(texts))
    loader = DataLoader(ds, batch_size=BATCH_SIZE)
    probs  = []
    with torch.no_grad():
        for batch in loader:
            logits = model(
                input_ids=batch["input_ids"].to(DEVICE),
                attention_mask=batch["attention_mask"].to(DEVICE),
            ).logits
            probs.extend(torch.softmax(logits, dim=1)[:, 1].cpu().numpy())
    return np.array(probs)

print("✅ Tokenizer ve yardımcı sınıflar hazır.")

# ============================================================
# HÜCRE 6 — AŞAMA 1: Genel BERT Eğitimi
# ⚠️  ~30–50 dk
# ============================================================
# @title Aşama 1 — Genel BERT

print("=" * 60)
print(" AŞAMA 1: Genel Zararlı İçerik Tespiti (tüm veri)")
print("=" * 60)

X_all = df_raw[TEXT].tolist()
y_all = df_raw[TARGET].astype(int).tolist()

X_tr, X_te, y_tr, y_te = train_test_split(X_all, y_all, test_size=0.2, random_state=42, stratify=y_all)
X_tr, X_va, y_tr, y_va = train_test_split(X_tr,  y_tr,  test_size=0.1, random_state=42, stratify=y_tr)

df_tr  = pd.DataFrame({"text": X_tr, "label": y_tr})
df_maj = df_tr[df_tr.label == 0]
df_min = df_tr[df_tr.label == 1]
df_min_up = resample(df_min, replace=True, n_samples=len(df_maj), random_state=42)
df_up = pd.concat([df_maj, df_min_up]).sample(frac=1, random_state=42)

train_loader = DataLoader(BinaryDataset(df_up["text"].tolist(), df_up["label"].tolist()), batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(BinaryDataset(X_va, y_va), batch_size=BATCH_SIZE)

bert_general = train_bert_model(train_loader, val_loader, num_labels=2, save_path="final_models/bert_general")

all_probs  = get_bert_probs(bert_general, X_te)
all_labels = np.array(y_te)

best_f1, best_thr, best_preds = -1, 0.5, None
for thr in np.linspace(0.3, 0.7, 20):
    preds = (all_probs >= thr).astype(int)
    f1    = precision_recall_fscore_support(all_labels, preds, average="binary")[2]
    if f1 > best_f1:
        best_f1, best_thr, best_preds = f1, thr, preds

joblib.dump({"threshold": best_thr}, "final_models/bert_general_config.pkl")
print(f"\n  Threshold: {best_thr:.2f} | F1: {best_f1:.4f}")
print("\n--- GENEL BERT TEST RAPORU ---")
print(classification_report(all_labels, best_preds, target_names=["Güvenli", "Zararlı"]))

cm = confusion_matrix(all_labels, best_preds)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Güvenli", "Zararlı"], yticklabels=["Güvenli", "Zararlı"])
plt.title(f"Genel BERT (thr={best_thr:.2f})")
plt.tight_layout(); plt.show()

# ============================================================
# HÜCRE 7 — AŞAMA 1: XGBoost Eğitimi
# ⚠️  ~15–20 dk
# ============================================================
# @title Aşama 1 — XGBoost

print("=" * 60)
print(" AŞAMA 1: XGBoost (tüm veri)")
print("=" * 60)

df_xgb = df_raw.copy()
df_xgb["text_len"] = df_xgb[TEXT].str.len()
df_xgb["word_cnt"] = df_xgb[TEXT].str.split().str.len()

age_dummies = pd.get_dummies(df_xgb[AGE_GROUP_COL], prefix="AgeGroup")
AGE_GROUP_COLUMNS = list(age_dummies.columns)
joblib.dump(AGE_GROUP_COLUMNS, "final_models/age_group_columns.pkl")
print(f"Age group sütunları: {AGE_GROUP_COLUMNS}")

X_meta = df_xgb[["text_len", "word_cnt"]]
y_xgb  = df_xgb[TARGET].astype(int)
texts  = df_xgb[TEXT]

(X_m_tr, X_m_te,
 y_tr_x, y_te_x,
 t_tr,   t_te,
 age_tr, age_te) = train_test_split(
    X_meta, y_xgb, texts, age_dummies,
    test_size=0.2, random_state=42, stratify=y_xgb,
)

vectorizer = TfidfVectorizer(max_features=5000, min_df=5)
X_tr_tfidf = vectorizer.fit_transform(t_tr)
X_te_tfidf = vectorizer.transform(t_te)

age_te     = age_te.reindex(columns=age_tr.columns, fill_value=0)
X_tr_final = hstack([X_tr_tfidf, csr_matrix(X_m_tr.values), csr_matrix(age_tr.values)])
X_te_final = hstack([X_te_tfidf, csr_matrix(X_m_te.values), csr_matrix(age_te.values)])

neg = (y_tr_x == 0).sum(); pos = (y_tr_x == 1).sum()
scale_pos_weight = neg / pos
print(f"scale_pos_weight = {scale_pos_weight:.3f}")

def xgb_objective(trial):
    params = {
        "n_estimators":     trial.suggest_int  ("n_estimators",     100, 800, step=50),
        "max_depth":        trial.suggest_int  ("max_depth",          3,  10),
        "learning_rate":    trial.suggest_float("learning_rate",    0.01, 0.3, log=True),
        "subsample":        trial.suggest_float("subsample",         0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree",  0.5, 1.0),
        "min_child_weight": trial.suggest_int  ("min_child_weight",    1,  10),
        "scale_pos_weight": scale_pos_weight,
        "eval_metric":      "logloss",
        "random_state":     42,
        "tree_method":      "hist",
        "device":           "cpu",  # sparse matrix CPU'da → model de CPU'da olmalı
    }
    clf = xgb.XGBClassifier(**params)
    clf.fit(X_tr_final, y_tr_x, verbose=False)
    preds = clf.predict(X_te_final)
    return precision_recall_fscore_support(y_te_x, preds, average="binary")[2]

print("Optuna araması (50 deneme)...")
study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(xgb_objective, n_trials=50, show_progress_bar=True)
print(f"✅ En iyi F1: {study.best_value:.4f} | Params: {study.best_params}")

best_xgb_params = {
    **study.best_params,
    "scale_pos_weight": scale_pos_weight,
    "eval_metric":      "logloss",
    "random_state":     42,
    "tree_method":      "hist",
    "device":           "cpu",
}
best_xgb = xgb.XGBClassifier(**best_xgb_params)
best_xgb.fit(X_tr_final, y_tr_x, verbose=False)

joblib.dump(best_xgb,   "final_models/xgboost_model.pkl")
joblib.dump(vectorizer, "final_models/tfidf_vectorizer.pkl")

y_pred_xgb = best_xgb.predict(X_te_final)
print("\n--- XGBOOST TEST RAPORU ---")
print(classification_report(y_te_x, y_pred_xgb, target_names=["Güvenli", "Zararlı"]))

cm_xgb = confusion_matrix(y_te_x, y_pred_xgb)
plt.figure(figsize=(5, 4))
sns.heatmap(cm_xgb, annot=True, fmt="d", cmap="Greens",
            xticklabels=["Güvenli", "Zararlı"], yticklabels=["Güvenli", "Zararlı"])
plt.title("XGBoost — Genel"); plt.tight_layout(); plt.show()

# ============================================================
# HÜCRE 8 — SHAP Doğrulaması
# ============================================================
# @title SHAP Analizi

feature_names = (
    vectorizer.get_feature_names_out().tolist()
    + ["text_len", "word_cnt"]
    + AGE_GROUP_COLUMNS
)

explainer   = shap.TreeExplainer(best_xgb)
X_sample    = X_te_final.toarray()[:200]
shap_values = explainer.shap_values(X_sample)

shap.summary_plot(shap_values, X_sample, feature_names=feature_names, max_display=15, show=True)
print("✅ SHAP grafiği hazır.")

# ============================================================
# HÜCRE 9 — AŞAMA 2: Yaş Grubu BERT Eğitimi
# ⚠️  ~20–30 dk
# ============================================================
# @title Aşama 2 — Yaş Grubu Sınıflandırması

print("=" * 60)
print(" AŞAMA 2: Yaş Grubu Sınıflandırması")
print("=" * 60)

df_age = df_raw[
    (df_raw[AGE_GROUP_COL] != "Unknown") &
    (df_raw[TARGET] == 1.0)
].copy()

def normalize_age_group(val):
    v = str(val).lower()
    if "under 11" in v or "younger" in v: return 0
    if "11" in v or "pre" in v:           return 1
    if "13" in v or "teen" in v:          return 2
    return -1

df_age["age_label"] = df_age[AGE_GROUP_COL].apply(normalize_age_group)
df_age = df_age[df_age["age_label"] >= 0]

print(f"Yaş grubu eğitim verisi: {len(df_age):,} zararlı örnek")
print(df_age["age_label"].value_counts().rename({0:"Younger", 1:"Pre-Teen", 2:"Teen"}))

X_age = df_age[TEXT].tolist()
y_age = df_age["age_label"].tolist()

X_tr_a, X_te_a, y_tr_a, y_te_a = train_test_split(X_age, y_age, test_size=0.2, random_state=42, stratify=y_age)
X_tr_a, X_va_a, y_tr_a, y_va_a = train_test_split(X_tr_a, y_tr_a, test_size=0.1, random_state=42, stratify=y_tr_a)

df_tr_a  = pd.DataFrame({"text": X_tr_a, "label": y_tr_a})
max_size = df_tr_a["label"].value_counts().max()
balanced = pd.concat([
    resample(df_tr_a[df_tr_a.label == cls], replace=True, n_samples=max_size, random_state=42)
    for cls in [0, 1, 2]
]).sample(frac=1, random_state=42)

train_loader_a = DataLoader(MultiClassDataset(balanced["text"].tolist(), balanced["label"].tolist()), batch_size=BATCH_SIZE, shuffle=True)
val_loader_a   = DataLoader(MultiClassDataset(X_va_a, y_va_a), batch_size=BATCH_SIZE)

bert_age = train_bert_model(train_loader_a, val_loader_a, num_labels=3, save_path="final_models/bert_age_group")

bert_age.eval()
all_preds_a, all_labels_a = [], []
with torch.no_grad():
    for batch in DataLoader(MultiClassDataset(X_te_a, y_te_a), batch_size=BATCH_SIZE):
        preds = bert_age(
            input_ids=batch["input_ids"].to(DEVICE),
            attention_mask=batch["attention_mask"].to(DEVICE),
        ).logits.argmax(dim=1).cpu().numpy()
        all_preds_a.extend(preds)
        all_labels_a.extend(batch["labels"].numpy())

print("\n--- YAŞ GRUBU SINIFLANDIRMA RAPORU ---")
print(classification_report(all_labels_a, all_preds_a, target_names=AGE_LABEL_NAMES))

cm_age = confusion_matrix(all_labels_a, all_preds_a)
plt.figure(figsize=(6, 5))
sns.heatmap(cm_age, annot=True, fmt="d", cmap="Purples",
            xticklabels=AGE_LABEL_NAMES, yticklabels=AGE_LABEL_NAMES)
plt.title("Yaş Grubu Sınıflandırıcı"); plt.tight_layout(); plt.show()

joblib.dump(AGE_LABEL_NAMES, "final_models/age_label_names.pkl")

# ============================================================
# HÜCRE 10 — ZIP + Drive'a Kaydet + İndir
# ============================================================
# @title Modelleri Kaydet

print("\n=== ÖZET ===")
for f in sorted(os.listdir("final_models")):
    path = os.path.join("final_models", f)
    if os.path.isdir(path):
        print(f"  📁 {f}/")
    else:
        print(f"  📄 {f}  ({os.path.getsize(path)/1024:.1f} KB)")

shutil.make_archive("ChildGuard_v2_Bundle", "zip", "final_models")
print("\n✅ ZIP hazır.")

# Drive'a kaydet — session kapansa bile kaybolmaz
os.makedirs(DRIVE_SAVE_DIR, exist_ok=True)
shutil.copy("ChildGuard_v2_Bundle.zip", f"{DRIVE_SAVE_DIR}/ChildGuard_v2_Bundle.zip")
print(f"✅ Drive'a kaydedildi: {DRIVE_SAVE_DIR}/ChildGuard_v2_Bundle.zip")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 89.8 MB/s eta 0:00:00
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Dataset bulundu: /content/drive/MyDrive/ChildGuard/ChildGuard_Cleaned.csv
# ✅ Ortam hazır.
#    PyTorch : 2.10.0+cu128
#    Device  : cuda
#    XGBoost : 3.2.0
# ✅ Dataset: 262,598 satır
#
# AGE GROUP:
# Age_Group
# Unknown                        220043
# Younger Children (Under 11)     28389
# Teens (13â€“17)                  9355
# Pre-Teens (11â€“12)              4811
# Name: count, dtype: int64
#
# ACTUAL CLASS:
# actual_class
# 0.0    218793
# 1.0     43805
# Name: count, dtype: int64
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ✅ Tokenizer ve yardımcı sınıflar hazır.
# ============================================================
#  AŞAMA 1: Genel Zararlı İçerik Tespiti (tüm veri)
# ============================================================
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Ep 1/3 Train:   0%|          | 0/19692 [00:00<?, ?batch/s]
# Ep 1/3 Val  :   0%|          | 0/1313 [00:00<?, ?batch/s]
#   → Epoch 1 | train_acc=0.8853 | val_acc=0.8967 ✅ en iyi
# Ep 2/3 Train:   0%|          | 0/19692 [00:00<?, ?batch/s]
# Ep 2/3 Val  :   0%|          | 0/1313 [00:00<?, ?batch/s]
#   → Epoch 2 | train_acc=0.9628 | val_acc=0.9078 ✅ en iyi
# Ep 3/3 Train:   0%|          | 0/19692 [00:00<?, ?batch/s]
# Ep 3/3 Val  :   0%|          | 0/1313 [00:00<?, ?batch/s]
#   → Epoch 3 | train_acc=0.9871 | val_acc=0.9139 ✅ en iyi
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
#   💾 Kaydedildi → final_models/bert_general  (best val_acc=0.9139)
#
#   Threshold: 0.32 | F1: 0.7462
#
# --- GENEL BERT TEST RAPORU ---
#               precision    recall  f1-score   support
#
#      Güvenli       0.95      0.95      0.95     43759
#      Zararlı       0.75      0.74      0.75      8761
#
#     accuracy                           0.92     52520
#    macro avg       0.85      0.85      0.85     52520
# weighted avg       0.92      0.92      0.92     52520
# ============================================================
#  AŞAMA 1: XGBoost (tüm veri)
# ============================================================
# Age group sütunları: ['AgeGroup_Pre-Teens (11â€“12)', 'AgeGroup_Teens (13â€“17)', 'AgeGroup_Unknown', 'AgeGroup_Younger Children (Under 11)']
# scale_pos_weight = 4.995
# Optuna araması (50 deneme)...
#   0%|          | 0/50 [00:00<?, ?it/s]
# ✅ En iyi F1: 0.6531 | Params: {'n_estimators': 800, 'max_depth': 10, 'learning_rate': 0.13582285325010435, 'subsample': 0.9692160792885414, 'colsample_bytree': 0.619827950261607, 'min_child_weight': 3}
#
# --- XGBOOST TEST RAPORU ---
#               precision    recall  f1-score   support
#
#      Güvenli       0.95      0.89      0.92     43759
#      Zararlı       0.57      0.76      0.65      8761
#
#     accuracy                           0.86     52520
#    macro avg       0.76      0.82      0.78     52520
# weighted avg       0.89      0.86      0.87     52520
# ✅ SHAP grafiği hazır.
# ============================================================
#  AŞAMA 2: Yaş Grubu Sınıflandırması
# ============================================================
# Yaş grubu eğitim verisi: 8,575 zararlı örnek
# age_label
# Younger     3543
# Teen        3503
# Pre-Teen    1529
# Name: count, dtype: int64
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Ep 1/3 Train:   0%|          | 0/479 [00:00<?, ?batch/s]
# Ep 1/3 Val  :   0%|          | 0/43 [00:00<?, ?batch/s]
#   → Epoch 1 | train_acc=0.6659 | val_acc=0.8834 ✅ en iyi
# Ep 2/3 Train:   0%|          | 0/479 [00:00<?, ?batch/s]
# Ep 2/3 Val  :   0%|          | 0/43 [00:00<?, ?batch/s]
#   → Epoch 2 | train_acc=0.9305 | val_acc=0.9286 ✅ en iyi
# Ep 3/3 Train:   0%|          | 0/479 [00:00<?, ?batch/s]
# Ep 3/3 Val  :   0%|          | 0/43 [00:00<?, ?batch/s]
#   → Epoch 3 | train_acc=0.9779 | val_acc=0.9315 ✅ en iyi
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
#   💾 Kaydedildi → final_models/bert_age_group  (best val_acc=0.9315)
#
# --- YAŞ GRUBU SINIFLANDIRMA RAPORU ---
#               precision    recall  f1-score   support
#
#      Younger       0.92      0.89      0.91       709
#     Pre-Teen       0.88      0.92      0.90       306
#         Teen       0.93      0.94      0.93       700
#
#     accuracy                           0.92      1715
#    macro avg       0.91      0.92      0.91      1715
# weighted avg       0.92      0.92      0.92      1715
# === ÖZET ===
#   📄 age_group_columns.pkl  (0.1 KB)
#   📄 age_label_names.pkl  (0.0 KB)
#   📁 bert_age_group/
#   📁 bert_general/
#   📄 bert_general_config.pkl  (0.1 KB)
#   📄 tfidf_vectorizer.pkl  (178.6 KB)
#   📄 xgboost_model.pkl  (3362.9 KB)
#
# ✅ ZIP hazır.
# ✅ Drive'a kaydedildi: /content/drive/MyDrive/ChildGuard/final_models_v2/ChildGuard_v2_Bundle.zip

# %%
import pickle

training_data = {
    "dataset_info": {
        "total": len(df_raw), "train": len(X_train),
        "val": len(X_val), "test": len(X_test),
        "class_dist": dict(df_raw[TARGET].value_counts()),
        "age_dist": dict(df_raw[AGE_GROUP_COL].value_counts()),
    },
    "bert_results": {},   # aşağıda doldurulacak
    "xgb_result": {
        "y_true": y_test.tolist(),
        "y_pred": y_pred_xgb.tolist(),
        "probs": xgb_probs.tolist(),
        "best_params": grid.best_params_,
    },
    "hybrid": {
        "y_true": y_test.tolist(),
        "final_scores": final_scores.tolist(),
        "bert_scores": bert_probs.tolist(),
        "xgb_scores": xgb_probs.tolist(),
    }
}

# BERT sonuçlarını döngüde zaten topladıysan:
for group_name, data in history.items():
    training_data["bert_results"][group_name] = {
        "y_true": data["y_true"].tolist(),
        "y_pred": data["y_pred"].tolist(),
        "threshold": data["threshold"],
        "probs": data.get("probs", []),
    }

with open("training_results.pkl", "wb") as f:
    pickle.dump(training_data, f)

files.download("training_results.pkl")

# %%
# Repo'yu Drive'a clone et
import os
os.chdir("/content/drive/MyDrive/ChildGuard")

import pandas as pd
import re

df = pd.read_csv("ChildGuard_repo/ChildGuard.csv", encoding="cp1252")

print(f"Toplam: {len(df):,}")
print(f"\nNull değerler:\n{df.isnull().sum()}")
print(f"\nActual class: {df['actual_class'].value_counts().to_dict()}")
print(f"\nAge_Group: {df['Age_Group'].value_counts().to_dict()}")

# Metin kalite sorunları
print(f"\nBoş metin: {(df['text'].str.strip() == '').sum()}")
print(f"Çok kısa (<10 karakter): {(df['text'].str.len() < 10).sum()}")
print(f"Çok uzun (>1000 karakter): {(df['text'].str.len() > 1000).sum()}")

# Tekrar eden metinler
print(f"Duplicate text: {df['text'].duplicated().sum():,}")

# Dil dışı içerik
non_ascii = df['text'].apply(lambda x: len(re.findall(r'[^\x00-\x7F]', str(x))) / max(len(str(x)), 1))
print(f"Yüksek non-ASCII oranı (>0.3): {(non_ascii > 0.3).sum():,}")
# Out:
# Toplam: 351,877
#
# Null değerler:
# text               59
# actual_class        0
# predicted_class     0
# Age_Group           0
# dtype: int64
#
# Actual class: {0: 286078, 1: 65799}
#
# Age_Group: {'Unknown': 300148, 'Younger Children (Under 11)': 34300, 'Teens (13–17)': 11479, 'Pre-Teens (11–12)': 5950}
#
# Boş metin: 0
# Çok kısa (<10 karakter): 35646
# Çok uzun (>1000 karakter): 12532
# Duplicate text: 30,830
# Yüksek non-ASCII oranı (>0.3): 0

# %%
import pandas as pd
import re

df_main = pd.read_csv("ChildGuard_repo/ChildGuard.csv", encoding="cp1252")
df_lex  = pd.read_csv("ChildGuard_repo/lexical_chilhate.csv", encoding="cp1252")
df_ctx  = pd.read_csv("ChildGuard_repo/contextual_childhate.csv", encoding="cp1252")

# Lexical ve Contextual'a Age_Group ekle
df_lex["Age_Group"] = "Unknown"
df_ctx["Age_Group"] = "Unknown"

# Contextual'daki extra kolonu kaldır
df_ctx = df_ctx.drop(columns=["contextual_score"], errors="ignore")

# Birleştir
df = pd.concat([df_main, df_lex, df_ctx], ignore_index=True)
print(f"Birleşik toplam: {len(df):,}")

# Temizleme
df = df.dropna(subset=["text", "actual_class"])          # null text
df = df[df["text"].str.strip() != ""]                    # boş metin
df = df[df["text"].str.len() >= 10]                      # çok kısa
df = df[df["text"].str.len() <= 1000]                    # çok uzun
df = df.drop_duplicates(subset=["text"])                 # duplicate

# Sütunları hizala
df = df[["text", "actual_class", "Age_Group"]]
df["actual_class"] = df["actual_class"].astype(float)

print(f"Temizleme sonrası: {len(df):,}")
print(f"\nActual class:\n{df['actual_class'].value_counts()}")
print(f"\nAge_Group:\n{df['Age_Group'].value_counts()}")

# Kaydet
df.to_csv("/content/drive/MyDrive/ChildGuard/ChildGuard_v3_Cleaned.csv", index=False)
print("\n✅ ChildGuard_v3_Cleaned.csv kaydedildi.")
# Out:
# Birleşik toplam: 703,754
# Temizleme sonrası: 277,980
#
# Actual class:
# actual_class
# 0.0    229431
# 1.0     48549
# Name: count, dtype: int64
#
# Age_Group:
# Age_Group
# Unknown                        238142
# Younger Children (Under 11)     25287
# Teens (13–17)                    9639
# Pre-Teens (11–12)                4912
# Name: count, dtype: int64
#
# ✅ ChildGuard_v3_Cleaned.csv kaydedildi.

# %%
import pandas as pd
import re

df_main = pd.read_csv("ChildGuard_repo/ChildGuard.csv", encoding="cp1252")
df_lex  = pd.read_csv("ChildGuard_repo/lexical_chilhate.csv", encoding="cp1252")
df_ctx  = pd.read_csv("ChildGuard_repo/contextual_childhate.csv", encoding="cp1252")

df_lex["Age_Group"] = "Unknown"
df_ctx["Age_Group"] = "Unknown"
df_ctx = df_ctx.drop(columns=["contextual_score"], errors="ignore")

df = pd.concat([df_main, df_lex, df_ctx], ignore_index=True)
print(f"Birleşik toplam: {len(df):,}")

df = df.dropna(subset=["text", "actual_class"])
df = df[df["text"].str.strip() != ""]
df = df[df["text"].str.len() >= 10]
df = df[df["text"].str.len() <= 1000]
df = df.drop_duplicates(subset=["text"])

df = df[["text", "actual_class", "Age_Group"]]
df["actual_class"] = df["actual_class"].astype(float)

print(f"Temizleme sonrası: {len(df):,}")
print(f"\nActual class:\n{df['actual_class'].value_counts()}")
print(f"\nAge_Group:\n{df['Age_Group'].value_counts()}")

df.to_csv("/content/drive/MyDrive/ChildGuard/ChildGuard_v3_Cleaned.csv", index=False)
print("\n✅ ChildGuard_v3_Cleaned.csv kaydedildi.")
# Out:
# Birleşik toplam: 703,754
# Temizleme sonrası: 277,980
#
# Actual class:
# actual_class
# 0.0    229431
# 1.0     48549
# Name: count, dtype: int64
#
# Age_Group:
# Age_Group
# Unknown                        238142
# Younger Children (Under 11)     25287
# Teens (13–17)                    9639
# Pre-Teens (11–12)                4912
# Name: count, dtype: int64
#
# ✅ ChildGuard_v3_Cleaned.csv kaydedildi.

# %%
# -*- coding: utf-8 -*-
"""ChildGuard AI v3.0 — Veri Temizleme + İki Aşamalı Eğitim (Google Colab)
W&B ile profesyonel experiment tracking
"""

# ============================================================
# HÜCRE 1 — Kurulum
# ============================================================
# @title Kurulum
# !pip install -q wandb
# !pip install -q "transformers==4.41.2" "tokenizers==0.19.1" \
             datasets accelerate joblib seaborn xgboost optuna shap ipywidgets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 69.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 132.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 40.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 48.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 88.0 MB/s eta 0:00:00

# %%
# ============================================================
# HÜCRE 2 — W&B + Drive Bağlantısı
# ============================================================
# @title W&B ve Drive

import wandb
wandb.login()

from google.colab import drive
drive.mount('/content/drive')

REPO_DIR       = "/content/drive/MyDrive/ChildGuard/ChildGuard_repo"
DRIVE_SAVE_DIR = "/content/drive/MyDrive/ChildGuard/final_models_v3"
WANDB_PROJECT  = "childguard-v3"

import os
for f in ["ChildGuard.csv", "lexical_chilhate.csv", "contextual_childhate.csv"]:
    path = f"{REPO_DIR}/{f}"
    print(f"{'✅' if os.path.exists(path) else '❌'} {f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:wandb: WARNING Invalid choice
# wandb: Enter your choice:
#  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
# wandb: WARNING Invalid choice
# wandb: Enter your choice:
#  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
# wandb: WARNING Invalid choice
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: omerozcan3808 (omerozcan3808-afyon-kocatepe-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Mounted at /content/drive
# ✅ ChildGuard.csv
# ✅ lexical_chilhate.csv
# ✅ contextual_childhate.csv

# %%
# ============================================================
# HÜCRE 3 — Import'lar ve Ayarlar
# ============================================================
# @title Import'lar

import os, re, shutil, time
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import torch
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from transformers import (
    BertTokenizer,
    BertForSequenceClassification,
    get_linear_schedule_with_warmup,
)
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import (
    accuracy_score, confusion_matrix,
    precision_recall_fscore_support, classification_report,
)
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack, csr_matrix
import xgboost as xgb
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)
import shap
from tqdm.auto import tqdm

TEXT           = "text"
TARGET         = "actual_class"
AGE_GROUP_COL  = "Age_Group"
MAX_LEN        = 128
BATCH_SIZE     = 16
EPOCHS         = 3
DEVICE         = torch.device("cuda" if torch.cuda.is_available() else "cpu")
AGE_LABEL_NAMES = ["Younger", "Pre-Teen", "Teen"]
REPO_DIR       = "/content/drive/MyDrive/ChildGuard/ChildGuard_repo"
DRIVE_SAVE_DIR = "/content/drive/MyDrive/ChildGuard/final_models_v3"
WANDB_PROJECT  = "childguard-v3"
os.makedirs("final_models", exist_ok=True)
print("✅ Ortam hazır.")
print(f"   PyTorch : {torch.__version__}")
print(f"   Device  : {DEVICE}")
print(f"   XGBoost : {xgb.__version__}")
# Out:
# ✅ Ortam hazır.
#    PyTorch : 2.10.0+cu128
#    Device  : cuda
#    XGBoost : 3.2.0

# %%
# ============================================================
# HÜCRE 4 — Veri Temizleme ve Birleştirme
# ============================================================
# @title Veri Temizleme

print("Veriler yükleniyor...")
df_main = pd.read_csv(f"{REPO_DIR}/ChildGuard.csv",           encoding="cp1252")
df_lex  = pd.read_csv(f"{REPO_DIR}/lexical_chilhate.csv",     encoding="cp1252")
df_ctx  = pd.read_csv(f"{REPO_DIR}/contextual_childhate.csv", encoding="cp1252")

df_lex["Age_Group"] = "Unknown"
df_ctx["Age_Group"] = "Unknown"
df_ctx = df_ctx.drop(columns=["contextual_score"], errors="ignore")

df = pd.concat([df_main, df_lex, df_ctx], ignore_index=True)
print(f"Birleşik toplam   : {len(df):,}")

before = len(df)
df = df.dropna(subset=[TEXT, TARGET])
df = df[df[TEXT].str.strip() != ""]
df = df[df[TEXT].str.len() >= 10]
df = df[df[TEXT].str.len() <= 1000]
df = df.drop_duplicates(subset=[TEXT])
df = df[[TEXT, TARGET, AGE_GROUP_COL]]
df[TARGET] = df[TARGET].astype(float)

def clean_text(text: str) -> str:
    text = str(text).lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"[^a-zA-Z0-9\s!?.,]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df[TEXT] = df[TEXT].apply(clean_text)
df = df[df[TEXT].str.strip() != ""]
df = df[df[TEXT].str.len() >= 10]

print(f"Temizleme sonrası : {len(df):,}  (düşen: {before - len(df):,})")
print(f"\nActual class:\n{df[TARGET].value_counts()}")
print(f"\nAge Group:\n{df[AGE_GROUP_COL].value_counts()}")

cleaned_path = "/content/drive/MyDrive/ChildGuard/ChildGuard_v3_Cleaned.csv"
df.to_csv(cleaned_path, index=False)
print(f"\n✅ Kaydedildi: {cleaned_path}")
# Out:
# Veriler yükleniyor...
# Birleşik toplam   : 703,754
# Temizleme sonrası : 276,641  (düşen: 427,113)
#
# Actual class:
# actual_class
# 0.0    228280
# 1.0     48361
# Name: count, dtype: int64
#
# Age Group:
# Age_Group
# Unknown                        236818
# Younger Children (Under 11)     25280
# Teens (13–17)                    9633
# Pre-Teens (11–12)                4910
# Name: count, dtype: int64
#
# ✅ Kaydedildi: /content/drive/MyDrive/ChildGuard/ChildGuard_v3_Cleaned.csv

# %%
# ============================================================
# HÜCRE 5 — Tokenizer ve Dataset Sınıfları
# ============================================================
# @title Tokenizer

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

class BinaryDataset(Dataset):
    def __init__(self, texts, labels):
        self.enc    = tokenizer(texts, truncation=True, padding=True,
                                max_length=MAX_LEN, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)
    def __len__(self): return len(self.labels)
    def __getitem__(self, idx):
        return {
            "input_ids":      self.enc["input_ids"][idx],
            "attention_mask": self.enc["attention_mask"][idx],
            "labels":         self.labels[idx],
        }

class MultiClassDataset(Dataset):
    def __init__(self, texts, labels):
        self.enc    = tokenizer(texts, truncation=True, padding=True,
                                max_length=MAX_LEN, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)
    def __len__(self): return len(self.labels)
    def __getitem__(self, idx):
        return {
            "input_ids":      self.enc["input_ids"][idx],
            "attention_mask": self.enc["attention_mask"][idx],
            "labels":         self.labels[idx],
        }

def get_bert_probs(model, texts):
    model.eval()
    ds     = BinaryDataset(texts, [0] * len(texts))
    loader = DataLoader(ds, batch_size=BATCH_SIZE)
    probs  = []
    with torch.no_grad():
        for batch in loader:
            logits = model(
                input_ids=batch["input_ids"].to(DEVICE),
                attention_mask=batch["attention_mask"].to(DEVICE),
            ).logits
            probs.extend(torch.softmax(logits, dim=1)[:, 1].cpu().numpy())
    return np.array(probs)

def train_bert_model(train_loader, val_loader, num_labels, save_path, run_name):
    model = BertForSequenceClassification.from_pretrained(
        "bert-base-uncased", num_labels=num_labels)
    model.to(DEVICE)

    optimizer   = AdamW(model.parameters(), lr=2e-5)
    total_steps = len(train_loader) * EPOCHS
    scheduler   = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=int(0.1 * total_steps),
        num_training_steps=total_steps,
    )

    wandb.config.update({
        f"{run_name}_lr":         2e-5,
        f"{run_name}_batch_size": BATCH_SIZE,
        f"{run_name}_epochs":     EPOCHS,
        f"{run_name}_num_labels": num_labels,
    }, allow_val_change=True)

    best_val_acc, best_state = 0.0, None
    epoch_metrics = []

    for epoch in range(EPOCHS):
        t0 = time.time()
        model.train()
        running_loss, correct_tr, total_tr = 0.0, 0, 0

        pbar = tqdm(train_loader, desc=f"[{run_name}] Ep {epoch+1}/{EPOCHS} Train",
                    unit="batch", leave=True)
        for step, batch in enumerate(pbar, 1):
            optimizer.zero_grad()
            out = model(
                input_ids=batch["input_ids"].to(DEVICE),
                attention_mask=batch["attention_mask"].to(DEVICE),
                labels=batch["labels"].to(DEVICE),
            )
            out.loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step(); scheduler.step()

            running_loss += out.loss.item()
            preds         = out.logits.argmax(dim=1).cpu()
            correct_tr   += (preds == batch["labels"]).sum().item()
            total_tr     += len(batch["labels"])
            pbar.set_postfix(
                loss=f"{running_loss/step:.4f}",
                acc=f"{correct_tr/total_tr:.4f}",
                lr=f"{scheduler.get_last_lr()[0]:.1e}",
            )

        model.eval()
        correct_v, total_v, val_loss = 0, 0, 0.0
        all_preds_v, all_labels_v = [], []

        vbar = tqdm(val_loader, desc=f"[{run_name}] Ep {epoch+1}/{EPOCHS} Val  ",
                    unit="batch", leave=True)
        with torch.no_grad():
            for batch in vbar:
                out_v = model(
                    input_ids=batch["input_ids"].to(DEVICE),
                    attention_mask=batch["attention_mask"].to(DEVICE),
                    labels=batch["labels"].to(DEVICE),
                )
                val_loss  += out_v.loss.item()
                preds_v    = out_v.logits.argmax(dim=1).cpu()
                correct_v += (preds_v == batch["labels"]).sum().item()
                total_v   += len(batch["labels"])
                all_preds_v.extend(preds_v.numpy())
                all_labels_v.extend(batch["labels"].numpy())
                vbar.set_postfix(
                    val_loss=f"{val_loss/(vbar.n+1):.4f}",
                    val_acc=f"{correct_v/total_v:.4f}",
                )

        val_acc   = correct_v / total_v
        train_acc = correct_tr / total_tr
        avg_train_loss = running_loss / len(train_loader)
        avg_val_loss   = val_loss / len(val_loader)
        epoch_time     = time.time() - t0

        if num_labels == 2:
            p, r, f1, _ = precision_recall_fscore_support(
                all_labels_v, all_preds_v, average="binary")
        else:
            p, r, f1, _ = precision_recall_fscore_support(
                all_labels_v, all_preds_v, average="macro")

        flag = " ✅ en iyi" if val_acc > best_val_acc else ""
        print(f"  → Epoch {epoch+1} | train_acc={train_acc:.4f} | "
              f"val_acc={val_acc:.4f} | val_f1={f1:.4f} | "
              f"time={epoch_time:.0f}s{flag}\n")

        wandb.log({
            f"{run_name}/train_loss":    avg_train_loss,
            f"{run_name}/train_acc":     train_acc,
            f"{run_name}/val_loss":      avg_val_loss,
            f"{run_name}/val_acc":       val_acc,
            f"{run_name}/val_f1":        f1,
            f"{run_name}/val_precision": p,
            f"{run_name}/val_recall":    r,
            f"{run_name}/epoch_time_s":  epoch_time,
            "epoch": epoch + 1,
        })

        epoch_metrics.append({
            "epoch":      epoch + 1,
            "train_loss": round(avg_train_loss, 4),
            "train_acc":  round(train_acc, 4),
            "val_loss":   round(avg_val_loss, 4),
            "val_acc":    round(val_acc, 4),
            "val_f1":     round(f1, 4),
        })

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state   = {k: v.clone() for k, v in model.state_dict().items()}

    model.load_state_dict(best_state)
    model.save_pretrained(save_path)
    tokenizer.save_pretrained(save_path)
    print(f"  💾 Kaydedildi → {save_path}  (best val_acc={best_val_acc:.4f})")
    return model, epoch_metrics

print("✅ Tokenizer ve yardımcı sınıflar hazır.")
# Out:
# ✅ Tokenizer ve yardımcı sınıflar hazır.

# %%
# ============================================================
# HÜCRE 6 — W&B Run Başlat
# ============================================================
# @title W&B Run Başlat
import wandb
from datetime import datetime
wandb.login()
run = wandb.init(
    project=WANDB_PROJECT,
    name=f"childguard-v3-{datetime.now().strftime('%Y%m%d-%H%M')}",
    config={
        "dataset":    "ChildGuard_v3_Cleaned",
        "bert_model": "bert-base-uncased",
        "batch_size": BATCH_SIZE,
        "epochs":     EPOCHS,
        "max_len":    MAX_LEN,
        "device":     str(DEVICE),
    }
)
print(f"✅ W&B run başladı: {run.url}")
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">childguard-v3-20260415-1247</strong> at: <a href='https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3/runs/wfm2kw4j' target="_blank">https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3/runs/wfm2kw4j</a><br> View project at: <a href='https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3' target="_blank">https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260415_124748-wfm2kw4j/logs</code>
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/content/wandb/run-20260415_125154-66ye54ze</code>
# Syncing run <strong><a href='https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3/runs/66ye54ze' target="_blank">childguard-v3-20260415-1251</a></strong> to <a href='https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3' target="_blank">https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3</a>
#  View run at <a href='https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3/runs/66ye54ze' target="_blank">https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3/runs/66ye54ze</a>
# ✅ W&B run başladı: https://wandb.ai/omerozcan3808-afyon-kocatepe-university/childguard-v3/runs/66ye54ze

# %%
# ============================================================
# HÜCRE 7 — AŞAMA 1: Genel BERT
# ⚠️  ~45–60 dk
# ============================================================
# @title Aşama 1 — Genel BERT

print("=" * 60)
print(" AŞAMA 1: Genel Zararlı İçerik Tespiti")
print("=" * 60)

X_all = df[TEXT].tolist()
y_all = df[TARGET].astype(int).tolist()

X_tr, X_te, y_tr, y_te = train_test_split(
    X_all, y_all, test_size=0.2, random_state=42, stratify=y_all)
X_tr, X_va, y_tr, y_va = train_test_split(
    X_tr, y_tr, test_size=0.1, random_state=42, stratify=y_tr)

wandb.log({
    "data/total_samples":  len(df),
    "data/train_samples":  len(X_tr),
    "data/val_samples":    len(X_va),
    "data/test_samples":   len(X_te),
    "data/harmful_ratio":  sum(y_all) / len(y_all),
})

df_tr  = pd.DataFrame({"text": X_tr, "label": y_tr})
df_maj = df_tr[df_tr.label == 0]
df_min = df_tr[df_tr.label == 1]
df_min_up = resample(df_min, replace=True, n_samples=len(df_maj), random_state=42)
df_up = pd.concat([df_maj, df_min_up]).sample(frac=1, random_state=42)

train_loader = DataLoader(
    BinaryDataset(df_up["text"].tolist(), df_up["label"].tolist()),
    batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(BinaryDataset(X_va, y_va), batch_size=BATCH_SIZE)

bert_general, bert_general_metrics = train_bert_model(
    train_loader, val_loader,
    num_labels=2,
    save_path="final_models/bert_general",
    run_name="bert_general",
)

all_probs  = get_bert_probs(bert_general, X_te)
all_labels = np.array(y_te)

best_f1, best_thr, best_preds = -1, 0.5, None
for thr in np.linspace(0.3, 0.7, 20):
    preds = (all_probs >= thr).astype(int)
    f1    = precision_recall_fscore_support(all_labels, preds, average="binary")[2]
    if f1 > best_f1:
        best_f1, best_thr, best_preds = f1, thr, preds

joblib.dump({"threshold": best_thr}, "final_models/bert_general_config.pkl")

p_te, r_te, f1_te, _ = precision_recall_fscore_support(all_labels, best_preds, average="binary")
acc_te = accuracy_score(all_labels, best_preds)

wandb.log({
    "bert_general/test_accuracy":  acc_te,
    "bert_general/test_f1":        f1_te,
    "bert_general/test_precision": p_te,
    "bert_general/test_recall":    r_te,
    "bert_general/best_threshold": best_thr,
})

print(f"\n  Threshold: {best_thr:.2f} | Test F1: {f1_te:.4f} | Acc: {acc_te:.4f}")
print(classification_report(all_labels, best_preds, target_names=["Güvenli", "Zararlı"]))

cm = confusion_matrix(all_labels, best_preds)
fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Güvenli", "Zararlı"],
            yticklabels=["Güvenli", "Zararlı"], ax=ax)
ax.set_title(f"BERT Genel (thr={best_thr:.2f})")
wandb.log({"bert_general/confusion_matrix": wandb.Image(fig)})
plt.tight_layout(); plt.show()

# ── Drive Yedek ──────────────────────────────────────────────
os.makedirs(DRIVE_SAVE_DIR, exist_ok=True)
shutil.copytree("final_models/bert_general",
                f"{DRIVE_SAVE_DIR}/bert_general",
                dirs_exist_ok=True)
shutil.copy("final_models/bert_general_config.pkl",
            f"{DRIVE_SAVE_DIR}/bert_general_config.pkl")
print(f"✅ bert_general Drive'a yedeklendi → {DRIVE_SAVE_DIR}/bert_general")
# Out:
# ============================================================
#  AŞAMA 1: Genel Zararlı İçerik Tespiti
# ============================================================
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [bert_general] Ep 1/3 Train:   0%|          | 0/20545 [00:00<?, ?batch/s]
# [bert_general] Ep 1/3 Val  :   0%|          | 0/1384 [00:00<?, ?batch/s]
#   → Epoch 1 | train_acc=0.8828 | val_acc=0.8873 | val_f1=0.7286 | time=1748s ✅ en iyi
# [bert_general] Ep 2/3 Train:   0%|          | 0/20545 [00:00<?, ?batch/s]

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

zip_path = "/content/drive/MyDrive/ChildGuard/final_models_v3/ChildGuard_v3_Bundle.zip"
print("ZIP:", "✅ var" if os.path.exists(zip_path) else "❌ yok")

print("\nfinal_models içeriği:")
if os.path.exists("final_models"):
    for f in sorted(os.listdir("final_models")):
        print(" -", f)
else:
    print("❌ final_models yok, session kapandı")
# Out:
# Mounted at /content/drive
# ZIP: ❌ yok
#
# final_models içeriği:
# ❌ final_models yok, session kapandı

# %%
# ============================================================
# HÜCRE 8 — AŞAMA 1: XGBoost
# ⚠️  ~20–30 dk
# ============================================================
# @title Aşama 1 — XGBoost

print("=" * 60)
print(" AŞAMA 1: XGBoost")
print("=" * 60)

df_xgb = df.copy()
df_xgb["text_len"] = df_xgb[TEXT].str.len()
df_xgb["word_cnt"] = df_xgb[TEXT].str.split().str.len()

age_dummies       = pd.get_dummies(df_xgb[AGE_GROUP_COL], prefix="AgeGroup")
AGE_GROUP_COLUMNS = list(age_dummies.columns)
joblib.dump(AGE_GROUP_COLUMNS, "final_models/age_group_columns.pkl")

X_meta = df_xgb[["text_len", "word_cnt"]]
y_xgb  = df_xgb[TARGET].astype(int)
texts  = df_xgb[TEXT]

(X_m_tr, X_m_te,
 y_tr_x, y_te_x,
 t_tr,   t_te,
 age_tr, age_te) = train_test_split(
    X_meta, y_xgb, texts, age_dummies,
    test_size=0.2, random_state=42, stratify=y_xgb,
)

vectorizer = TfidfVectorizer(max_features=5000, min_df=5)
X_tr_tfidf = vectorizer.fit_transform(t_tr)
X_te_tfidf = vectorizer.transform(t_te)

age_te     = age_te.reindex(columns=age_tr.columns, fill_value=0)
X_tr_final = hstack([X_tr_tfidf, csr_matrix(X_m_tr.values), csr_matrix(age_tr.values)])
X_te_final = hstack([X_te_tfidf, csr_matrix(X_m_te.values), csr_matrix(age_te.values)])

neg = (y_tr_x == 0).sum(); pos = (y_tr_x == 1).sum()
scale_pos_weight = neg / pos
print(f"scale_pos_weight = {scale_pos_weight:.3f}")

def xgb_objective(trial):
    params = {
        "n_estimators":     trial.suggest_int  ("n_estimators",     100, 800, step=50),
        "max_depth":        trial.suggest_int  ("max_depth",          3,  10),
        "learning_rate":    trial.suggest_float("learning_rate",    0.01, 0.3, log=True),
        "subsample":        trial.suggest_float("subsample",         0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree",  0.5, 1.0),
        "min_child_weight": trial.suggest_int  ("min_child_weight",    1,  10),
        "scale_pos_weight": scale_pos_weight,
        "eval_metric":      "logloss",
        "random_state":     42,
        "tree_method":      "hist",
        "device":           "cpu",
    }
    clf = xgb.XGBClassifier(**params)
    clf.fit(X_tr_final, y_tr_x, verbose=False)
    preds = clf.predict(X_te_final)
    f1 = precision_recall_fscore_support(y_te_x, preds, average="binary")[2]
    wandb.log({"xgb/trial_f1": f1, "xgb/trial": trial.number})
    return f1

print("Optuna araması (50 deneme)...")
study = optuna.create_study(direction="maximize",
                            sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(xgb_objective, n_trials=50, show_progress_bar=True)
print(f"✅ En iyi F1: {study.best_value:.4f}")

best_xgb_params = {
    **study.best_params,
    "scale_pos_weight": scale_pos_weight,
    "eval_metric": "logloss",
    "random_state": 42,
    "tree_method": "hist",
    "device": "cpu",
}
best_xgb = xgb.XGBClassifier(**best_xgb_params)
best_xgb.fit(X_tr_final, y_tr_x, verbose=False)

joblib.dump(best_xgb,   "final_models/xgboost_model.pkl")
joblib.dump(vectorizer, "final_models/tfidf_vectorizer.pkl")

y_pred_xgb = best_xgb.predict(X_te_final)
p_x, r_x, f1_x, _ = precision_recall_fscore_support(y_te_x, y_pred_xgb, average="binary")
acc_x = accuracy_score(y_te_x, y_pred_xgb)

wandb.log({
    "xgb/test_accuracy":  acc_x,
    "xgb/test_f1":        f1_x,
    "xgb/test_precision": p_x,
    "xgb/test_recall":    r_x,
})

print(classification_report(y_te_x, y_pred_xgb, target_names=["Güvenli", "Zararlı"]))

cm_xgb = confusion_matrix(y_te_x, y_pred_xgb)
fig2, ax2 = plt.subplots(figsize=(5, 4))
sns.heatmap(cm_xgb, annot=True, fmt="d", cmap="Greens",
            xticklabels=["Güvenli", "Zararlı"],
            yticklabels=["Güvenli", "Zararlı"], ax=ax2)
ax2.set_title("XGBoost — Genel")
wandb.log({"xgb/confusion_matrix": wandb.Image(fig2)})
plt.tight_layout(); plt.show()
# Out:
# ============================================================
#  AŞAMA 1: XGBoost
# ============================================================
# scale_pos_weight = 4.720
# Optuna araması (50 deneme)...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# ============================================================
# HÜCRE 9 — SHAP
# ============================================================
# @title SHAP

feature_names = (
    vectorizer.get_feature_names_out().tolist()
    + ["text_len", "word_cnt"]
    + AGE_GROUP_COLUMNS
)
explainer   = shap.TreeExplainer(best_xgb)
X_sample    = X_te_final.toarray()[:200]
shap_values = explainer.shap_values(X_sample)

fig3, ax3 = plt.subplots(figsize=(10, 6))
shap.summary_plot(shap_values, X_sample, feature_names=feature_names,
                  max_display=15, show=False)
wandb.log({"xgb/shap_summary": wandb.Image(fig3)})
plt.tight_layout(); plt.show()
print("✅ SHAP hazır.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_564/2304812981.py in <cell line: 0>()
#       5
#       6 feature_names = (
# ----> 7     vectorizer.get_feature_names_out().tolist()
#       8     + ["text_len", "word_cnt"]
#       9     + AGE_GROUP_COLUMNS
#
# NameError: name 'vectorizer' is not defined

# %%
# ============================================================
# HÜCRE 10 — AŞAMA 2: Yaş Grubu BERT
# ⚠️  ~20–30 dk
# ============================================================
# @title Aşama 2 — Yaş Grubu

print("=" * 60)
print(" AŞAMA 2: Yaş Grubu Sınıflandırması")
print("=" * 60)

df_age = df[
    (~df[AGE_GROUP_COL].str.contains("Unknown", case=False, na=False)) &
    (df[TARGET] == 1.0)
].copy()

def normalize_age_group(val):
    v = str(val).lower()
    if "under 11" in v or "younger" in v: return 0
    if "11" in v or "pre" in v:           return 1
    if "13" in v or "teen" in v:          return 2
    return -1

df_age["age_label"] = df_age[AGE_GROUP_COL].apply(normalize_age_group)
df_age = df_age[df_age["age_label"] >= 0]

print(f"Yaş grubu: {len(df_age):,} zararlı örnek")
print(df_age["age_label"].value_counts().rename({0:"Younger",1:"Pre-Teen",2:"Teen"}))

X_age = df_age[TEXT].tolist()
y_age = df_age["age_label"].tolist()

X_tr_a, X_te_a, y_tr_a, y_te_a = train_test_split(
    X_age, y_age, test_size=0.2, random_state=42, stratify=y_age)
X_tr_a, X_va_a, y_tr_a, y_va_a = train_test_split(
    X_tr_a, y_tr_a, test_size=0.1, random_state=42, stratify=y_tr_a)

df_tr_a  = pd.DataFrame({"text": X_tr_a, "label": y_tr_a})
max_size = df_tr_a["label"].value_counts().max()
balanced = pd.concat([
    resample(df_tr_a[df_tr_a.label == cls],
             replace=True, n_samples=max_size, random_state=42)
    for cls in [0, 1, 2]
]).sample(frac=1, random_state=42)

train_loader_a = DataLoader(
    MultiClassDataset(balanced["text"].tolist(), balanced["label"].tolist()),
    batch_size=BATCH_SIZE, shuffle=True)
val_loader_a = DataLoader(MultiClassDataset(X_va_a, y_va_a), batch_size=BATCH_SIZE)

bert_age, bert_age_metrics = train_bert_model(
    train_loader_a, val_loader_a,
    num_labels=3,
    save_path="final_models/bert_age_group",
    run_name="bert_age",
)

bert_age.eval()
all_preds_a, all_labels_a = [], []
with torch.no_grad():
    for batch in DataLoader(MultiClassDataset(X_te_a, y_te_a), batch_size=BATCH_SIZE):
        preds = bert_age(
            input_ids=batch["input_ids"].to(DEVICE),
            attention_mask=batch["attention_mask"].to(DEVICE),
        ).logits.argmax(dim=1).cpu().numpy()
        all_preds_a.extend(preds)
        all_labels_a.extend(batch["labels"].numpy())

p_a, r_a, f1_a, _ = precision_recall_fscore_support(
    all_labels_a, all_preds_a, average="macro")
acc_a = accuracy_score(all_labels_a, all_preds_a)

wandb.log({
    "bert_age/test_accuracy":  acc_a,
    "bert_age/test_f1_macro":  f1_a,
    "bert_age/test_precision": p_a,
    "bert_age/test_recall":    r_a,
})

print(classification_report(all_labels_a, all_preds_a, target_names=AGE_LABEL_NAMES))

cm_age = confusion_matrix(all_labels_a, all_preds_a)
fig4, ax4 = plt.subplots(figsize=(6, 5))
sns.heatmap(cm_age, annot=True, fmt="d", cmap="Purples",
            xticklabels=AGE_LABEL_NAMES, yticklabels=AGE_LABEL_NAMES, ax=ax4)
ax4.set_title("Yaş Grubu Sınıflandırıcı")
wandb.log({"bert_age/confusion_matrix": wandb.Image(fig4)})
plt.tight_layout(); plt.show()

joblib.dump(AGE_LABEL_NAMES, "final_models/age_label_names.pkl")

# %%
# ============================================================
# HÜCRE 11 — Özet + ZIP + Drive + W&B Finish
# ============================================================
# @title Özet ve İndir

wandb.summary.update({
    "bert_general_test_acc":  acc_te,
    "bert_general_test_f1":   f1_te,
    "xgb_test_acc":           acc_x,
    "xgb_test_f1":            f1_x,
    "bert_age_test_acc":      acc_a,
    "bert_age_test_f1_macro": f1_a,
    "best_threshold":         best_thr,
    "dataset_size":           len(df),
})

print("\n=== ÖZET ===")
print(f"  BERT Genel → acc={acc_te:.4f}  F1={f1_te:.4f}  thr={best_thr:.2f}")
print(f"  XGBoost    → acc={acc_x:.4f}  F1={f1_x:.4f}")
print(f"  BERT Yaş   → acc={acc_a:.4f}  F1={f1_a:.4f} (macro)")

shutil.make_archive("ChildGuard_v3_Bundle", "zip", "final_models")
os.makedirs(DRIVE_SAVE_DIR, exist_ok=True)
shutil.copy("ChildGuard_v3_Bundle.zip", f"{DRIVE_SAVE_DIR}/ChildGuard_v3_Bundle.zip")
print(f"\n✅ Drive'a kaydedildi: {DRIVE_SAVE_DIR}/ChildGuard_v3_Bundle.zip")

wandb.finish()
print("✅ W&B run tamamlandı.")

from google.colab import files
files.download("ChildGuard_v3_Bundle.zip")

# %%
# -*- coding: utf-8 -*-
"""ChildGuard AI v3.0 — Veri Temizleme + İki Aşamalı Eğitim (Google Colab)
W&B ile profesyonel experiment tracking
"""

# ============================================================
# HÜCRE 1 — Kurulum
# ============================================================
# @title Kurulum
# !pip install -q wandb
# !pip install -q "torch==2.4.0" "transformers==4.44.0" datasets accelerate \
             joblib seaborn xgboost optuna shap ipywidgets

# ============================================================
# HÜCRE 2 — W&B + Drive Bağlantısı
# ============================================================
# @title W&B ve Drive

import wandb
wandb.login()

from google.colab import drive
drive.mount('/content/drive')

REPO_DIR       = "/content/drive/MyDrive/ChildGuard/ChildGuard_repo"
DRIVE_SAVE_DIR = "/content/drive/MyDrive/ChildGuard/final_models_v3"
WANDB_PROJECT  = "childguard-v3"

import os
for f in ["ChildGuard.csv", "lexical_chilhate.csv", "contextual_childhate.csv"]:
    path = f"{REPO_DIR}/{f}"
    print(f"{'✅' if os.path.exists(path) else '❌'} {f}")

# ============================================================
# HÜCRE 3 — Import'lar ve Ayarlar
# ============================================================
# @title Import'lar

import os, re, shutil, time
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import torch
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from transformers import (
    BertTokenizer,
    BertForSequenceClassification,
    get_linear_schedule_with_warmup,
)
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import (
    accuracy_score, confusion_matrix,
    precision_recall_fscore_support, classification_report,
)
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack, csr_matrix
import xgboost as xgb
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)
import shap
from tqdm.auto import tqdm

TEXT           = "text"
TARGET         = "actual_class"
AGE_GROUP_COL  = "Age_Group"
MAX_LEN        = 128
BATCH_SIZE     = 16
EPOCHS         = 3
DEVICE         = torch.device("cuda" if torch.cuda.is_available() else "cpu")
AGE_LABEL_NAMES = ["Younger", "Pre-Teen", "Teen"]

os.makedirs("final_models", exist_ok=True)
print("✅ Ortam hazır.")
print(f"   PyTorch : {torch.__version__}")
print(f"   Device  : {DEVICE}")
print(f"   XGBoost : {xgb.__version__}")

# ============================================================
# HÜCRE 4 — Veri Temizleme ve Birleştirme
# ============================================================
# @title Veri Temizleme

print("Veriler yükleniyor...")
df_main = pd.read_csv(f"{REPO_DIR}/ChildGuard.csv",           encoding="cp1252")
df_lex  = pd.read_csv(f"{REPO_DIR}/lexical_chilhate.csv",     encoding="cp1252")
df_ctx  = pd.read_csv(f"{REPO_DIR}/contextual_childhate.csv", encoding="cp1252")

df_lex["Age_Group"] = "Unknown"
df_ctx["Age_Group"] = "Unknown"
df_ctx = df_ctx.drop(columns=["contextual_score"], errors="ignore")

df = pd.concat([df_main, df_lex, df_ctx], ignore_index=True)
print(f"Birleşik toplam   : {len(df):,}")

before = len(df)
df = df.dropna(subset=[TEXT, TARGET])
df = df[df[TEXT].str.strip() != ""]
df = df[df[TEXT].str.len() >= 10]
df = df[df[TEXT].str.len() <= 1000]
df = df.drop_duplicates(subset=[TEXT])
df = df[[TEXT, TARGET, AGE_GROUP_COL]]
df[TARGET] = df[TARGET].astype(float)

def clean_text(text: str) -> str:
    text = str(text).lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"[^a-zA-Z0-9\s!?.,]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df[TEXT] = df[TEXT].apply(clean_text)
df = df[df[TEXT].str.strip() != ""]
df = df[df[TEXT].str.len() >= 10]

print(f"Temizleme sonrası : {len(df):,}  (düşen: {before - len(df):,})")
print(f"\nActual class:\n{df[TARGET].value_counts()}")
print(f"\nAge Group:\n{df[AGE_GROUP_COL].value_counts()}")

cleaned_path = "/content/drive/MyDrive/ChildGuard/ChildGuard_v3_Cleaned.csv"
df.to_csv(cleaned_path, index=False)
print(f"\n✅ Kaydedildi: {cleaned_path}")

# ============================================================
# HÜCRE 5 — Tokenizer ve Dataset Sınıfları
# ============================================================
# @title Tokenizer

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

class BinaryDataset(Dataset):
    def __init__(self, texts, labels):
        self.enc    = tokenizer(texts, truncation=True, padding=True,
                                max_length=MAX_LEN, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)
    def __len__(self): return len(self.labels)
    def __getitem__(self, idx):
        return {
            "input_ids":      self.enc["input_ids"][idx],
            "attention_mask": self.enc["attention_mask"][idx],
            "labels":         self.labels[idx],
        }

class MultiClassDataset(Dataset):
    def __init__(self, texts, labels):
        self.enc    = tokenizer(texts, truncation=True, padding=True,
                                max_length=MAX_LEN, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)
    def __len__(self): return len(self.labels)
    def __getitem__(self, idx):
        return {
            "input_ids":      self.enc["input_ids"][idx],
            "attention_mask": self.enc["attention_mask"][idx],
            "labels":         self.labels[idx],
        }

def get_bert_probs(model, texts):
    model.eval()
    ds     = BinaryDataset(texts, [0] * len(texts))
    loader = DataLoader(ds, batch_size=BATCH_SIZE)
    probs  = []
    with torch.no_grad():
        for batch in loader:
            logits = model(
                input_ids=batch["input_ids"].to(DEVICE),
                attention_mask=batch["attention_mask"].to(DEVICE),
            ).logits
            probs.extend(torch.softmax(logits, dim=1)[:, 1].cpu().numpy())
    return np.array(probs)

def train_bert_model(train_loader, val_loader, num_labels, save_path, run_name):
    model = BertForSequenceClassification.from_pretrained(
        "bert-base-uncased", num_labels=num_labels)
    model.to(DEVICE)

    optimizer   = AdamW(model.parameters(), lr=2e-5)
    total_steps = len(train_loader) * EPOCHS
    scheduler   = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=int(0.1 * total_steps),
        num_training_steps=total_steps,
    )

    wandb.config.update({
        f"{run_name}_lr":         2e-5,
        f"{run_name}_batch_size": BATCH_SIZE,
        f"{run_name}_epochs":     EPOCHS,
        f"{run_name}_num_labels": num_labels,
    }, allow_val_change=True)

    best_val_acc, best_state = 0.0, None
    epoch_metrics = []

    for epoch in range(EPOCHS):
        t0 = time.time()
        model.train()
        running_loss, correct_tr, total_tr = 0.0, 0, 0

        pbar = tqdm(train_loader, desc=f"[{run_name}] Ep {epoch+1}/{EPOCHS} Train",
                    unit="batch", leave=True)
        for step, batch in enumerate(pbar, 1):
            optimizer.zero_grad()
            out = model(
                input_ids=batch["input_ids"].to(DEVICE),
                attention_mask=batch["attention_mask"].to(DEVICE),
                labels=batch["labels"].to(DEVICE),
            )
            out.loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step(); scheduler.step()

            running_loss += out.loss.item()
            preds         = out.logits.argmax(dim=1).cpu()
            correct_tr   += (preds == batch["labels"]).sum().item()
            total_tr     += len(batch["labels"])
            pbar.set_postfix(
                loss=f"{running_loss/step:.4f}",
                acc=f"{correct_tr/total_tr:.4f}",
                lr=f"{scheduler.get_last_lr()[0]:.1e}",
            )

        model.eval()
        correct_v, total_v, val_loss = 0, 0, 0.0
        all_preds_v, all_labels_v = [], []

        vbar = tqdm(val_loader, desc=f"[{run_name}] Ep {epoch+1}/{EPOCHS} Val  ",
                    unit="batch", leave=True)
        with torch.no_grad():
            for batch in vbar:
                out_v = model(
                    input_ids=batch["input_ids"].to(DEVICE),
                    attention_mask=batch["attention_mask"].to(DEVICE),
                    labels=batch["labels"].to(DEVICE),
                )
                val_loss  += out_v.loss.item()
                preds_v    = out_v.logits.argmax(dim=1).cpu()
                correct_v += (preds_v == batch["labels"]).sum().item()
                total_v   += len(batch["labels"])
                all_preds_v.extend(preds_v.numpy())
                all_labels_v.extend(batch["labels"].numpy())
                vbar.set_postfix(
                    val_loss=f"{val_loss/(vbar.n+1):.4f}",
                    val_acc=f"{correct_v/total_v:.4f}",
                )

        val_acc   = correct_v / total_v
        train_acc = correct_tr / total_tr
        avg_train_loss = running_loss / len(train_loader)
        avg_val_loss   = val_loss / len(val_loader)
        epoch_time     = time.time() - t0

        if num_labels == 2:
            p, r, f1, _ = precision_recall_fscore_support(
                all_labels_v, all_preds_v, average="binary")
        else:
            p, r, f1, _ = precision_recall_fscore_support(
                all_labels_v, all_preds_v, average="macro")

        flag = " ✅ en iyi" if val_acc > best_val_acc else ""
        print(f"  → Epoch {epoch+1} | train_acc={train_acc:.4f} | "
              f"val_acc={val_acc:.4f} | val_f1={f1:.4f} | "
              f"time={epoch_time:.0f}s{flag}\n")

        wandb.log({
            f"{run_name}/train_loss":    avg_train_loss,
            f"{run_name}/train_acc":     train_acc,
            f"{run_name}/val_loss":      avg_val_loss,
            f"{run_name}/val_acc":       val_acc,
            f"{run_name}/val_f1":        f1,
            f"{run_name}/val_precision": p,
            f"{run_name}/val_recall":    r,
            f"{run_name}/epoch_time_s":  epoch_time,
            "epoch": epoch + 1,
        })

        epoch_metrics.append({
            "epoch":      epoch + 1,
            "train_loss": round(avg_train_loss, 4),
            "train_acc":  round(train_acc, 4),
            "val_loss":   round(avg_val_loss, 4),
            "val_acc":    round(val_acc, 4),
            "val_f1":     round(f1, 4),
        })

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state   = {k: v.clone() for k, v in model.state_dict().items()}

    model.load_state_dict(best_state)
    model.save_pretrained(save_path)
    tokenizer.save_pretrained(save_path)
    print(f"  💾 Kaydedildi → {save_path}  (best val_acc={best_val_acc:.4f})")
    return model, epoch_metrics

print("✅ Tokenizer ve yardımcı sınıflar hazır.")

# ============================================================
# HÜCRE 6 — W&B Run Başlat
# ============================================================
# @title W&B Run Başlat

run = wandb.init(
    project=WANDB_PROJECT,
    name=f"childguard-v3-{datetime.now().strftime('%Y%m%d-%H%M')}",
    config={
        "dataset":    "ChildGuard_v3_Cleaned",
        "bert_model": "bert-base-uncased",
        "batch_size": BATCH_SIZE,
        "epochs":     EPOCHS,
        "max_len":    MAX_LEN,
        "device":     str(DEVICE),
    }
)
print(f"✅ W&B run başladı: {run.url}")

# ============================================================
# HÜCRE 7 — AŞAMA 1: Genel BERT
# ⚠️  ~45–60 dk
# ============================================================
# @title Aşama 1 — Genel BERT

print("=" * 60)
print(" AŞAMA 1: Genel Zararlı İçerik Tespiti")
print("=" * 60)

X_all = df[TEXT].tolist()
y_all = df[TARGET].astype(int).tolist()

X_tr, X_te, y_tr, y_te = train_test_split(
    X_all, y_all, test_size=0.2, random_state=42, stratify=y_all)
X_tr, X_va, y_tr, y_va = train_test_split(
    X_tr, y_tr, test_size=0.1, random_state=42, stratify=y_tr)

wandb.log({
    "data/total_samples":  len(df),
    "data/train_samples":  len(X_tr),
    "data/val_samples":    len(X_va),
    "data/test_samples":   len(X_te),
    "data/harmful_ratio":  sum(y_all) / len(y_all),
})

df_tr  = pd.DataFrame({"text": X_tr, "label": y_tr})
df_maj = df_tr[df_tr.label == 0]
df_min = df_tr[df_tr.label == 1]
df_min_up = resample(df_min, replace=True, n_samples=len(df_maj), random_state=42)
df_up = pd.concat([df_maj, df_min_up]).sample(frac=1, random_state=42)

train_loader = DataLoader(
    BinaryDataset(df_up["text"].tolist(), df_up["label"].tolist()),
    batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(BinaryDataset(X_va, y_va), batch_size=BATCH_SIZE)

bert_general, bert_general_metrics = train_bert_model(
    train_loader, val_loader,
    num_labels=2,
    save_path="final_models/bert_general",
    run_name="bert_general",
)

all_probs  = get_bert_probs(bert_general, X_te)
all_labels = np.array(y_te)

best_f1, best_thr, best_preds = -1, 0.5, None
for thr in np.linspace(0.3, 0.7, 20):
    preds = (all_probs >= thr).astype(int)
    f1    = precision_recall_fscore_support(all_labels, preds, average="binary")[2]
    if f1 > best_f1:
        best_f1, best_thr, best_preds = f1, thr, preds

joblib.dump({"threshold": best_thr}, "final_models/bert_general_config.pkl")

p_te, r_te, f1_te, _ = precision_recall_fscore_support(all_labels, best_preds, average="binary")
acc_te = accuracy_score(all_labels, best_preds)

wandb.log({
    "bert_general/test_accuracy":  acc_te,
    "bert_general/test_f1":        f1_te,
    "bert_general/test_precision": p_te,
    "bert_general/test_recall":    r_te,
    "bert_general/best_threshold": best_thr,
})

print(f"\n  Threshold: {best_thr:.2f} | Test F1: {f1_te:.4f} | Acc: {acc_te:.4f}")
print(classification_report(all_labels, best_preds, target_names=["Güvenli", "Zararlı"]))

cm = confusion_matrix(all_labels, best_preds)
fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Güvenli", "Zararlı"],
            yticklabels=["Güvenli", "Zararlı"], ax=ax)
ax.set_title(f"BERT Genel (thr={best_thr:.2f})")
wandb.log({"bert_general/confusion_matrix": wandb.Image(fig)})
plt.tight_layout(); plt.show()

# ============================================================
# HÜCRE 8 — AŞAMA 1: XGBoost
# ⚠️  ~20–30 dk
# ============================================================
# @title Aşama 1 — XGBoost

print("=" * 60)
print(" AŞAMA 1: XGBoost")
print("=" * 60)

df_xgb = df.copy()
df_xgb["text_len"] = df_xgb[TEXT].str.len()
df_xgb["word_cnt"] = df_xgb[TEXT].str.split().str.len()

age_dummies       = pd.get_dummies(df_xgb[AGE_GROUP_COL], prefix="AgeGroup")
AGE_GROUP_COLUMNS = list(age_dummies.columns)
joblib.dump(AGE_GROUP_COLUMNS, "final_models/age_group_columns.pkl")

X_meta = df_xgb[["text_len", "word_cnt"]]
y_xgb  = df_xgb[TARGET].astype(int)
texts  = df_xgb[TEXT]

(X_m_tr, X_m_te,
 y_tr_x, y_te_x,
 t_tr,   t_te,
 age_tr, age_te) = train_test_split(
    X_meta, y_xgb, texts, age_dummies,
    test_size=0.2, random_state=42, stratify=y_xgb,
)

vectorizer = TfidfVectorizer(max_features=5000, min_df=5)
X_tr_tfidf = vectorizer.fit_transform(t_tr)
X_te_tfidf = vectorizer.transform(t_te)

age_te     = age_te.reindex(columns=age_tr.columns, fill_value=0)
X_tr_final = hstack([X_tr_tfidf, csr_matrix(X_m_tr.values), csr_matrix(age_tr.values)])
X_te_final = hstack([X_te_tfidf, csr_matrix(X_m_te.values), csr_matrix(age_te.values)])

neg = (y_tr_x == 0).sum(); pos = (y_tr_x == 1).sum()
scale_pos_weight = neg / pos
print(f"scale_pos_weight = {scale_pos_weight:.3f}")

def xgb_objective(trial):
    params = {
        "n_estimators":     trial.suggest_int  ("n_estimators",     100, 800, step=50),
        "max_depth":        trial.suggest_int  ("max_depth",          3,  10),
        "learning_rate":    trial.suggest_float("learning_rate",    0.01, 0.3, log=True),
        "subsample":        trial.suggest_float("subsample",         0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree",  0.5, 1.0),
        "min_child_weight": trial.suggest_int  ("min_child_weight",    1,  10),
        "scale_pos_weight": scale_pos_weight,
        "eval_metric":      "logloss",
        "random_state":     42,
        "tree_method":      "hist",
        "device":           "cpu",
    }
    clf = xgb.XGBClassifier(**params)
    clf.fit(X_tr_final, y_tr_x, verbose=False)
    preds = clf.predict(X_te_final)
    f1 = precision_recall_fscore_support(y_te_x, preds, average="binary")[2]
    wandb.log({"xgb/trial_f1": f1, "xgb/trial": trial.number})
    return f1

print("Optuna araması (50 deneme)...")
study = optuna.create_study(direction="maximize",
                            sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(xgb_objective, n_trials=50, show_progress_bar=True)
print(f"✅ En iyi F1: {study.best_value:.4f}")

best_xgb_params = {
    **study.best_params,
    "scale_pos_weight": scale_pos_weight,
    "eval_metric": "logloss",
    "random_state": 42,
    "tree_method": "hist",
    "device": "cpu",
}
best_xgb = xgb.XGBClassifier(**best_xgb_params)
best_xgb.fit(X_tr_final, y_tr_x, verbose=False)

joblib.dump(best_xgb,   "final_models/xgboost_model.pkl")
joblib.dump(vectorizer, "final_models/tfidf_vectorizer.pkl")

y_pred_xgb = best_xgb.predict(X_te_final)
p_x, r_x, f1_x, _ = precision_recall_fscore_support(y_te_x, y_pred_xgb, average="binary")
acc_x = accuracy_score(y_te_x, y_pred_xgb)

wandb.log({
    "xgb/test_accuracy":  acc_x,
    "xgb/test_f1":        f1_x,
    "xgb/test_precision": p_x,
    "xgb/test_recall":    r_x,
})

print(classification_report(y_te_x, y_pred_xgb, target_names=["Güvenli", "Zararlı"]))

cm_xgb = confusion_matrix(y_te_x, y_pred_xgb)
fig2, ax2 = plt.subplots(figsize=(5, 4))
sns.heatmap(cm_xgb, annot=True, fmt="d", cmap="Greens",
            xticklabels=["Güvenli", "Zararlı"],
            yticklabels=["Güvenli", "Zararlı"], ax=ax2)
ax2.set_title("XGBoost — Genel")
wandb.log({"xgb/confusion_matrix": wandb.Image(fig2)})
plt.tight_layout(); plt.show()

# ============================================================
# HÜCRE 9 — SHAP
# ============================================================
# @title SHAP

feature_names = (
    vectorizer.get_feature_names_out().tolist()
    + ["text_len", "word_cnt"]
    + AGE_GROUP_COLUMNS
)
explainer   = shap.TreeExplainer(best_xgb)
X_sample    = X_te_final.toarray()[:200]
shap_values = explainer.shap_values(X_sample)

fig3, ax3 = plt.subplots(figsize=(10, 6))
shap.summary_plot(shap_values, X_sample, feature_names=feature_names,
                  max_display=15, show=False)
wandb.log({"xgb/shap_summary": wandb.Image(fig3)})
plt.tight_layout(); plt.show()
print("✅ SHAP hazır.")

# ============================================================
# HÜCRE 10 — AŞAMA 2: Yaş Grubu BERT
# ⚠️  ~20–30 dk
# ============================================================
# @title Aşama 2 — Yaş Grubu

print("=" * 60)
print(" AŞAMA 2: Yaş Grubu Sınıflandırması")
print("=" * 60)

df_age = df[
    (~df[AGE_GROUP_COL].str.contains("Unknown", case=False, na=False)) &
    (df[TARGET] == 1.0)
].copy()

def normalize_age_group(val):
    v = str(val).lower()
    if "under 11" in v or "younger" in v: return 0
    if "11" in v or "pre" in v:           return 1
    if "13" in v or "teen" in v:          return 2
    return -1

df_age["age_label"] = df_age[AGE_GROUP_COL].apply(normalize_age_group)
df_age = df_age[df_age["age_label"] >= 0]

print(f"Yaş grubu: {len(df_age):,} zararlı örnek")
print(df_age["age_label"].value_counts().rename({0:"Younger",1:"Pre-Teen",2:"Teen"}))

X_age = df_age[TEXT].tolist()
y_age = df_age["age_label"].tolist()

X_tr_a, X_te_a, y_tr_a, y_te_a = train_test_split(
    X_age, y_age, test_size=0.2, random_state=42, stratify=y_age)
X_tr_a, X_va_a, y_tr_a, y_va_a = train_test_split(
    X_tr_a, y_tr_a, test_size=0.1, random_state=42, stratify=y_tr_a)

df_tr_a  = pd.DataFrame({"text": X_tr_a, "label": y_tr_a})
max_size = df_tr_a["label"].value_counts().max()
balanced = pd.concat([
    resample(df_tr_a[df_tr_a.label == cls],
             replace=True, n_samples=max_size, random_state=42)
    for cls in [0, 1, 2]
]).sample(frac=1, random_state=42)

train_loader_a = DataLoader(
    MultiClassDataset(balanced["text"].tolist(), balanced["label"].tolist()),
    batch_size=BATCH_SIZE, shuffle=True)
val_loader_a = DataLoader(MultiClassDataset(X_va_a, y_va_a), batch_size=BATCH_SIZE)

bert_age, bert_age_metrics = train_bert_model(
    train_loader_a, val_loader_a,
    num_labels=3,
    save_path="final_models/bert_age_group",
    run_name="bert_age",
)

bert_age.eval()
all_preds_a, all_labels_a = [], []
with torch.no_grad():
    for batch in DataLoader(MultiClassDataset(X_te_a, y_te_a), batch_size=BATCH_SIZE):
        preds = bert_age(
            input_ids=batch["input_ids"].to(DEVICE),
            attention_mask=batch["attention_mask"].to(DEVICE),
        ).logits.argmax(dim=1).cpu().numpy()
        all_preds_a.extend(preds)
        all_labels_a.extend(batch["labels"].numpy())

p_a, r_a, f1_a, _ = precision_recall_fscore_support(
    all_labels_a, all_preds_a, average="macro")
acc_a = accuracy_score(all_labels_a, all_preds_a)

wandb.log({
    "bert_age/test_accuracy":  acc_a,
    "bert_age/test_f1_macro":  f1_a,
    "bert_age/test_precision": p_a,
    "bert_age/test_recall":    r_a,
})

print(classification_report(all_labels_a, all_preds_a, target_names=AGE_LABEL_NAMES))

cm_age = confusion_matrix(all_labels_a, all_preds_a)
fig4, ax4 = plt.subplots(figsize=(6, 5))
sns.heatmap(cm_age, annot=True, fmt="d", cmap="Purples",
            xticklabels=AGE_LABEL_NAMES, yticklabels=AGE_LABEL_NAMES, ax=ax4)
ax4.set_title("Yaş Grubu Sınıflandırıcı")
wandb.log({"bert_age/confusion_matrix": wandb.Image(fig4)})
plt.tight_layout(); plt.show()

joblib.dump(AGE_LABEL_NAMES, "final_models/age_label_names.pkl")

# ============================================================
# HÜCRE 11 — Özet + ZIP + Drive + W&B Finish
# ============================================================
# @title Özet ve İndir

wandb.summary.update({
    "bert_general_test_acc":  acc_te,
    "bert_general_test_f1":   f1_te,
    "xgb_test_acc":           acc_x,
    "xgb_test_f1":            f1_x,
    "bert_age_test_acc":      acc_a,
    "bert_age_test_f1_macro": f1_a,
    "best_threshold":         best_thr,
    "dataset_size":           len(df),
})

print("\n=== ÖZET ===")
print(f"  BERT Genel → acc={acc_te:.4f}  F1={f1_te:.4f}  thr={best_thr:.2f}")
print(f"  XGBoost    → acc={acc_x:.4f}  F1={f1_x:.4f}")
print(f"  BERT Yaş   → acc={acc_a:.4f}  F1={f1_a:.4f} (macro)")

shutil.make_archive("ChildGuard_v3_Bundle", "zip", "final_models")
os.makedirs(DRIVE_SAVE_DIR, exist_ok=True)
shutil.copy("ChildGuard_v3_Bundle.zip", f"{DRIVE_SAVE_DIR}/ChildGuard_v3_Bundle.zip")
print(f"\n✅ Drive'a kaydedildi: {DRIVE_SAVE_DIR}/ChildGuard_v3_Bundle.zip")

wandb.finish()
print("✅ W&B run tamamlandı.")

from google.colab import files
files.download("ChildGuard_v3_Bundle.zip")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 167.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 136.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 112.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 61.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 51.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 126.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.25.0+cu128 requires torch==2.10.0, but you have torch 2.4.0 which is incompatible.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.4.0 which is incompatible.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ ChildGuard.csv
# ✅ lexical_chilhate.csv
# ✅ contextual_childhate.csv
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_396/2355802175.py in <cell line: 0>()
#      46 from torch.utils.data import Dataset, DataLoader
#      47 from torch.optim import AdamW
# ---> 48 from transformers import (
#      49     BertTokenizer,
#      50     BertForSequenceClassification,
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/bert/modeling_bert.py in <module>
#      44     TokenClassifierOutput,
#      45 )
# ---> 46 from ...modeling_utils import PreTrainedModel
#      47 from ...pytorch_utils import apply_chunking_to_forward, find_pruneable_heads_and_indices, prune_linear_layer
#      48 from ...utils import (
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py in <module>
#      44 from .configuration_utils import PretrainedConfig
#      45 from .dynamic_module_utils import custom_object_save
# ---> 46 from .generation import GenerationConfig, GenerationMixin
#      47 from .integrations import PeftAdapterMixin, deepspeed_config, is_deepspeed_zero3_enabled
#      48 from .pytorch_utils import (  # noqa: F401
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in <module>
#      26 from torch.nn import functional as F
#      27
# ---> 28 from ..cache_utils import (
#      29     Cache,
#      30     DynamicCache,
#
# ImportError: cannot import name 'HQQQuantizedCache' from 'transformers.cache_utils' (/usr/local/lib/python3.12/dist-packages/transformers/cache_utils.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
